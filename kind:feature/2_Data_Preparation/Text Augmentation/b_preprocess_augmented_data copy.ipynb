# %%
import pandas as pd
from spacy.cli import download
from sklearn.feature_extraction.text import CountVectorizer
from collections import Counter
import spacy

# %%
train_data = pd.read_csv('../../../Data/Preprocessed Data/kind:feature/Augmented Data/Unprocessed Data/augmented_data_with_gpt2.csv')
val_data = pd.read_csv('../../../Data/Preprocessed Data/kind:feature/Augmented Data/Unprocessed Data/val_data.csv')

# %%
train_data.head()
# Out:
#                                         comments_url         id  \
# 0  https://api.github.com/repos/kubernetes/kubern...  275859420
# 1  https://api.github.com/repos/kubernetes/kubead...  262492428
# 2  https://api.github.com/repos/kubernetes/kubern...  275470204
# 3  https://api.github.com/repos/kubernetes/kubern...  274962003
# 4  https://api.github.com/repos/kubernetes/kubern...  388343406
#
#                                                title  \
# 0  Kubelet flag precedence order vs files/ConfigM...
# 1             Individual control of preflight checks
# 2  seccomp is an alpha feature and not feature gated
# 3  kubeletconfig API group is missing a fuzzer ro...
# 4       api timeouts when using token authentication
#
#                                                 body  \
# 0  See https://docs.google.com/document/d/18-MsCh...
# 1  Many times users know better than kubeadm arou...
# 2                                         see #55983
# 3                          Solution: I will add one.
# 4  <!-- Please use this template while reporting ...
#
#                                            issue_url  \
# 0  https://github.com/kubernetes/kubernetes/issue...
# 1   https://github.com/kubernetes/kubeadm/issues/480
# 2  https://github.com/kubernetes/kubernetes/issue...
# 3  https://github.com/kubernetes/kubernetes/issue...
# 4  https://github.com/kubernetes/kubernetes/issue...
#
#                                               pr_url  \
# 0  https://github.com/kubernetes/kubernetes/pull/...
# 1  https://github.com/kubernetes/kubernetes/pull/...
# 2  https://github.com/kubernetes/kubernetes/pull/...
# 3  https://github.com/kubernetes/kubernetes/pull/...
# 4  https://github.com/kubernetes/kubernetes/pull/...
#
#                                  labels  pr_number  \
# 0  ['area/kubelet', 'area/kubelet-api']    56097.0
# 1                      ['area/kubeadm']    56072.0
# 2  ['area/kubelet', 'area/kubelet-api']    55983.0
# 3                  ['area/kubelet-api']    55961.0
# 4                    ['area/apiserver']    71816.0
#
#                                             filename  \
# 0  ['cmd/kubelet/kubelet.go', 'hack/make-rules/te...
# 1  ['cmd/kubeadm/app/apis/kubeadm/validation/BUIL...
# 2  ['cmd/kubelet/app/options/options.go', 'cmd/ku...
# 3  ['pkg/kubelet/apis/kubeletconfig/BUILD', 'pkg/...
# 4  ['cmd/kube-apiserver/app/server.go', 'pkg/cont...
#
#                                               status  \
# 0  ['modified', 'modified', 'modified', 'modified...
# 1  ['modified', 'modified', 'modified', 'modified...
# 2  ['modified', 'modified', 'modified', 'modified...
# 3  ['modified', 'added', 'added', 'modified', 'ad...
# 4  ['modified', 'modified', 'modified', 'modified...
#
#                                            additions  \
# 0         [7, 1, 21, 1, 1, 1, 1, 1, 1, 15, 139, 146]
# 1  [1, 26, 29, 20, 21, 1, 3, 17, 4, 2, 6, 3, 5, 6...
# 2                        [5, 6, 0, 0, 0, 0, 0, 0, 5]
# 3                            [1, 32, 100, 12, 32, 6]
# 4                          [6, 16, 2, 35, 2, 34, 10]
#
#                                            deletions  \
# 0               [1, 0, 4, 0, 0, 1, 1, 1, 1, 0, 9, 0]
# 1  [0, 1, 0, 14, 15, 0, 2, 9, 0, 0, 1, 7, 1, 0, 0...
# 2                        [1, 3, 1, 1, 2, 4, 2, 2, 3]
# 3                                 [0, 0, 0, 1, 0, 6]
# 4                              [1, 3, 0, 1, 0, 1, 3]
#
#                                              changes  \
# 0         [8, 1, 25, 1, 1, 2, 2, 2, 2, 15, 148, 146]
# 1  [1, 27, 29, 34, 36, 1, 5, 26, 4, 2, 7, 10, 6, ...
# 2                        [6, 9, 1, 1, 2, 4, 2, 2, 8]
# 3                           [1, 32, 100, 13, 32, 12]
# 4                          [7, 19, 2, 36, 2, 35, 13]
#
#                                         all_comments  \
# 0                                                NaN
# 1  New example in 1.8.0:\r\nsystemctl start kubel...
# 2                                                NaN
# 3  /cc @luxas xref #55961  Thanks for sending a P...
# 4  @kubernetes/sig-auth-bugs @jmcmeek: Reiteratin...
#
#                                             all_text  is_augmented
# 0  kubelet flag precedence order vs dangerous see...         False
# 1  individual control preflight checks many times...         False
# 2     seccomp an alpha feature not feature gated see         False
# 3  kubeletconfig api group missing fuzzer round t...         False
# 4  api timeouts when using token authentication p...         False

# %%
# check for null values
train_data.isnull().sum()
# Out:
# comments_url    3515
# id                 0
# title              0
# body               3
# issue_url       3515
# pr_url          3515
# labels             0
# pr_number       3515
# filename        3515
# status          3515
# additions       3515
# deletions       3515
# changes         3515
# all_comments    3539
# all_text           3
# is_augmented       0
# dtype: int64

# %%
val_data.head()
# Out:
#                                         comments_url          id  \
# 0  https://api.github.com/repos/kubernetes/kubern...   985253828
# 1  https://api.github.com/repos/kubernetes/kubern...   985253828
# 2  https://api.github.com/repos/kubernetes/kubern...  1402736660
# 3  https://api.github.com/repos/kubernetes/kubern...  1343665057
# 4  https://api.github.com/repos/kubernetes/kubern...  1343665057
#
#                                                title  \
# 0        Make scheduling directives mutable for Jobs
# 1        Make scheduling directives mutable for Jobs
# 2  Introduce `MatchLabelKeys` (the same one as Po...
# 3  [KMSv2] Add additional logging with UID and me...
# 4  [KMSv2] Add additional logging with UID and me...
#
#                                                 body  \
# 0  #### What would you like to be added:\r\n\r\nM...
# 1  #### What would you like to be added:\r\n\r\nM...
# 2  ### What would you like to be added?\r\n\r\nIn...
# 3  Add additional logging at level `6` that assoc...
# 4  Add additional logging at level `6` that assoc...
#
#                                            issue_url  \
# 0  https://github.com/kubernetes/kubernetes/issue...
# 1  https://github.com/kubernetes/kubernetes/issue...
# 2  https://github.com/kubernetes/kubernetes/issue...
# 3  https://github.com/kubernetes/kubernetes/issue...
# 4  https://github.com/kubernetes/kubernetes/issue...
#
#                                               pr_url  \
# 0  https://github.com/kubernetes/kubernetes/pull/...
# 1  https://github.com/kubernetes/kubernetes/pull/...
# 2  https://github.com/kubernetes/kubernetes/pull/...
# 3  https://github.com/kubernetes/kubernetes/pull/...
# 4  https://github.com/kubernetes/kubernetes/pull/...
#
#                                   labels  pr_number  \
# 0                          ['area/test']     105479
# 1                          ['area/test']     116116
# 2  ['area/test', 'area/code-generation']     116065
# 3                     ['area/apiserver']     112153
# 4                     ['area/apiserver']     116055
#
#                                             filename  \
# 0  ['pkg/apis/batch/validation/validation.go', 'p...
# 1  ['pkg/features/kube_features.go', 'pkg/registr...
# 2  ['api/openapi-spec/swagger.json', 'api/openapi...
# 3  ['staging/src/k8s.io/apiserver/pkg/storage/val...
# 4  ['staging/src/k8s.io/apiserver/pkg/storage/val...
#
#                                               status  \
# 0  ['modified', 'modified', 'modified', 'modified...
# 1   ['modified', 'modified', 'modified', 'modified']
# 2  ['modified', 'modified', 'modified', 'modified...
# 3                                       ['modified']
# 4                           ['modified', 'modified']
#
#                                            additions  \
# 0                          [33, 190, 9, 10, 102, 76]
# 1                                      [2, 1, 3, 49]
# 2  [17, 19, 19, 19, 78, 856, 19, 4, 80, 711, 10, ...
# 3                                                [3]
# 4                                           [17, 91]
#
#                                            deletions  \
# 0                                 [4, 4, 0, 1, 5, 0]
# 1                                     [1, 2, 32, 64]
# 2  [1, 1, 1, 1, 7, 1, 0, 0, 3, 6, 0, 0, 1, 0, 0, ...
# 3                                                [0]
# 4                                             [2, 0]
#
#                                              changes  \
# 0                          [37, 194, 9, 11, 107, 76]
# 1                                    [3, 3, 35, 113]
# 2  [18, 20, 20, 20, 85, 857, 19, 4, 83, 717, 10, ...
# 3                                                [3]
# 4                                           [19, 91]
#
#                                         all_comments  \
# 0  /cc @soltysh @liggitt @wojtek-t  Two questions...
# 1  /cc @soltysh @liggitt @wojtek-t  Two questions...
# 2  @sanposhiho: This issue is currently awaiting ...
# 3  /triage accepted /milestone v1.26 @aramase @en...
# 4  /triage accepted /milestone v1.26 @aramase @en...
#
#                                             all_text
# 0  make scheduling directives mutable jobs make n...
# 1  make scheduling directives mutable jobs make n...
# 2  introduce same one pod topology introduce do p...
# 3  add additional logging with uid metadata add a...
# 4  add additional logging with uid metadata add a...

# %%
val_data.isnull().sum()
# Out:
# comments_url    0
# id              0
# title           0
# body            2
# issue_url       0
# pr_url          0
# labels          0
# pr_number       0
# filename        0
# status          0
# additions       0
# deletions       0
# changes         0
# all_comments    2
# all_text        2
# dtype: int64

# %%
# remove all_text that have null values
train_data = train_data[train_data['all_text'].notnull()]
val_data = val_data[val_data['all_text'].notnull()]

# remove all_text that has value 'NaN ' or 'nan'
train_data = train_data[~train_data['all_text'].isin(['NaN ', 'nan'])]
val_data = val_data[~val_data['all_text'].isin(['NaN ', 'nan'])]

# %% [markdown]
# Check the label distribution

# %%
# Flatten the list of labels if it's a list of lists
flattened_labels = []
for label_list in train_data["labels"]:
    # Convert string representation of list to actual list
    if isinstance(label_list, str):
        # Remove brackets and split by comma
        clean_label_list = label_list.strip('[]').replace("'", "").split(', ')
    else:
        clean_label_list = label_list
    
    # Add each label to the flattened list
    flattened_labels.extend(clean_label_list)

# Print labels distribution count
label_counts = Counter(flattened_labels)
print("Label Distribution Count (Training Data):")

for i, (label, count) in enumerate(label_counts.most_common()):
    print(f"{i+1}. {label}: {count}")
# Out:
# Label Distribution Count (Training Data):
# 1. area/test: 328
# 2. area/kubelet: 248
# 3. area/kubelet-api: 248
# 4. area/kubeadm: 248
# 5. area/kubectl: 248
# 6. area/code-generation: 248
# 7. area/conformance: 248
# 8. area/cloudprovider: 248
# 9. area/provider/azure: 248
# 10. area/ipvs: 248
# 11. area/e2e-test-framework: 248
# 12. area/custom-resources: 248
# 13. area/admission-control: 248
# 14. area/provider/gcp: 248
# 15. area/kube-proxy: 248
# 16. area/dependency: 246
# 17. area/release-eng: 246
# 18. area/apiserver: 245

# %%
# Flatten the list of labels if it's a list of lists
flattened_labels = []
for label_list in val_data["labels"]:
    # Convert string representation of list to actual list
    if isinstance(label_list, str):
        # Remove brackets and split by comma
        clean_label_list = label_list.strip('[]').replace("'", "").split(', ')
    else:
        clean_label_list = label_list
    
    # Add each label to the flattened list
    flattened_labels.extend(clean_label_list)

# Print labels distribution count
label_counts = Counter(flattened_labels)
print("Label Distribution Count (Validation Data):")

for i, (label, count) in enumerate(label_counts.most_common()):
    print(f"{i+1}. {label}: {count}")
# Out:
# Label Distribution Count (Validation Data):
# 1. area/test: 100
# 2. area/kubelet: 57
# 3. area/apiserver: 37
# 4. area/kubectl: 23
# 5. area/code-generation: 22
# 6. area/e2e-test-framework: 17
# 7. area/kubeadm: 11
# 8. area/kube-proxy: 7
# 9. area/release-eng: 3
# 10. area/provider/gcp: 3
# 11. area/conformance: 2
# 12. area/cloudprovider: 2
# 13. area/dependency: 2

# %% [markdown]
# Stopwords Removal

# %%
# remove stopwords using spaCy
try:
    nlp = spacy.load('en_core_web_sm')
except OSError:
    download('en_core_web_sm')
    nlp = spacy.load('en_core_web_sm')

train_data['all_text'] = train_data['all_text'].apply(lambda x: ' '.join([word.text for word in nlp(x) if not word.is_stop]))
val_data['all_text'] = val_data['all_text'].apply(lambda x: ' '.join([word.text for word in nlp(x) if not word.is_stop]))

# %%
# check null values in all_text column
# Display null values for all columns
print(f"Null all_text column : {train_data['all_text'].isnull().sum()}")
# Out:
# Null all_text column : 0

# %% [markdown]
# Data Lemmatization

# %%
# lematize the text using spaCy
train_data['all_text'] = train_data['all_text'].apply(lambda x: ' '.join([word.lemma_ for word in nlp(x)]))
val_data['all_text'] = val_data['all_text'].apply(lambda x: ' '.join([word.lemma_ for word in nlp(x)]))

# %%
# check all_text column for null values
print(f"Null all_text column : {train_data['all_text'].isnull().sum()}")
# Out:
# Null all_text column : 0

# %% [markdown]
# Add filename to the text

# %%
# add filename to the data
# Only append filename if it exists (not null/None)
train_data['all_text'] = train_data.apply(lambda row: row['all_text'] + ' ' + row['filename'] if pd.notna(row['filename']) else row['all_text'], axis=1)
val_data['all_text'] = val_data.apply(lambda row: row['all_text'] + ' ' + row['filename'] if pd.notna(row['filename']) else row['all_text'], axis=1)

# %%
# check all_text column for null values
print(f"Null all_text column : {train_data['all_text'].isnull().sum()}")
# Out:
# Null all_text column : 0

# %% [markdown]
# # Export the Data

# %%
train_data.head()
# Out:
#                                         comments_url         id  \
# 0  https://api.github.com/repos/kubernetes/kubern...  275859420
# 1  https://api.github.com/repos/kubernetes/kubead...  262492428
# 2  https://api.github.com/repos/kubernetes/kubern...  275470204
# 3  https://api.github.com/repos/kubernetes/kubern...  274962003
# 4  https://api.github.com/repos/kubernetes/kubern...  388343406
#
#                                                title  \
# 0  Kubelet flag precedence order vs files/ConfigM...
# 1             Individual control of preflight checks
# 2  seccomp is an alpha feature and not feature gated
# 3  kubeletconfig API group is missing a fuzzer ro...
# 4       api timeouts when using token authentication
#
#                                                 body  \
# 0  See https://docs.google.com/document/d/18-MsCh...
# 1  Many times users know better than kubeadm arou...
# 2                                         see #55983
# 3                          Solution: I will add one.
# 4  <!-- Please use this template while reporting ...
#
#                                            issue_url  \
# 0  https://github.com/kubernetes/kubernetes/issue...
# 1   https://github.com/kubernetes/kubeadm/issues/480
# 2  https://github.com/kubernetes/kubernetes/issue...
# 3  https://github.com/kubernetes/kubernetes/issue...
# 4  https://github.com/kubernetes/kubernetes/issue...
#
#                                               pr_url  \
# 0  https://github.com/kubernetes/kubernetes/pull/...
# 1  https://github.com/kubernetes/kubernetes/pull/...
# 2  https://github.com/kubernetes/kubernetes/pull/...
# 3  https://github.com/kubernetes/kubernetes/pull/...
# 4  https://github.com/kubernetes/kubernetes/pull/...
#
#                                  labels  pr_number  \
# 0  ['area/kubelet', 'area/kubelet-api']    56097.0
# 1                      ['area/kubeadm']    56072.0
# 2  ['area/kubelet', 'area/kubelet-api']    55983.0
# 3                  ['area/kubelet-api']    55961.0
# 4                    ['area/apiserver']    71816.0
#
#                                             filename  \
# 0  ['cmd/kubelet/kubelet.go', 'hack/make-rules/te...
# 1  ['cmd/kubeadm/app/apis/kubeadm/validation/BUIL...
# 2  ['cmd/kubelet/app/options/options.go', 'cmd/ku...
# 3  ['pkg/kubelet/apis/kubeletconfig/BUILD', 'pkg/...
# 4  ['cmd/kube-apiserver/app/server.go', 'pkg/cont...
#
#                                               status  \
# 0  ['modified', 'modified', 'modified', 'modified...
# 1  ['modified', 'modified', 'modified', 'modified...
# 2  ['modified', 'modified', 'modified', 'modified...
# 3  ['modified', 'added', 'added', 'modified', 'ad...
# 4  ['modified', 'modified', 'modified', 'modified...
#
#                                            additions  \
# 0         [7, 1, 21, 1, 1, 1, 1, 1, 1, 15, 139, 146]
# 1  [1, 26, 29, 20, 21, 1, 3, 17, 4, 2, 6, 3, 5, 6...
# 2                        [5, 6, 0, 0, 0, 0, 0, 0, 5]
# 3                            [1, 32, 100, 12, 32, 6]
# 4                          [6, 16, 2, 35, 2, 34, 10]
#
#                                            deletions  \
# 0               [1, 0, 4, 0, 0, 1, 1, 1, 1, 0, 9, 0]
# 1  [0, 1, 0, 14, 15, 0, 2, 9, 0, 0, 1, 7, 1, 0, 0...
# 2                        [1, 3, 1, 1, 2, 4, 2, 2, 3]
# 3                                 [0, 0, 0, 1, 0, 6]
# 4                              [1, 3, 0, 1, 0, 1, 3]
#
#                                              changes  \
# 0         [8, 1, 25, 1, 1, 2, 2, 2, 2, 15, 148, 146]
# 1  [1, 27, 29, 34, 36, 1, 5, 26, 4, 2, 7, 10, 6, ...
# 2                        [6, 9, 1, 1, 2, 4, 2, 2, 8]
# 3                           [1, 32, 100, 13, 32, 12]
# 4                          [7, 19, 2, 36, 2, 35, 13]
#
#                                         all_comments  \
# 0                                                NaN
# 1  New example in 1.8.0:\r\nsystemctl start kubel...
# 2                                                NaN
# 3  /cc @luxas xref #55961  Thanks for sending a P...
# 4  @kubernetes/sig-auth-bugs @jmcmeek: Reiteratin...
#
#                                             all_text  is_augmented
# 0  kubelet flag precedence order vs dangerous doc...         False
# 1  individual control preflight check time user k...         False
# 2  seccomp alpha feature feature gate ['cmd/kubel...         False
# 3  kubeletconfig api group miss fuzzer round trip...         False
# 4  api timeout token authentication use template ...         False

# %%
# count nan values in the train_data
train_data.isna().sum()
# Out:
# comments_url    3515
# id                 0
# title              0
# body               0
# issue_url       3515
# pr_url          3515
# labels             0
# pr_number       3515
# filename        3515
# status          3515
# additions       3515
# deletions       3515
# changes         3515
# all_comments    3538
# all_text           0
# is_augmented       0
# dtype: int64

# %%
# export the train_data and val_data to csv
train_data.to_csv('../../../Data/Preprocessed Data/kind:feature/Augmented Data/Preprocessed Data/preprocessed_train_data.csv', index=False)
val_data.to_csv('../../../Data/Preprocessed Data/kind:feature/Augmented Data/Preprocessed Data/preprocessed_val_data.csv', index=False)
