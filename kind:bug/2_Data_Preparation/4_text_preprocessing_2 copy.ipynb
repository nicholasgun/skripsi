# %%
import pandas as pd
from spacy.cli import download
from sklearn.feature_extraction.text import CountVectorizer
import spacy

# %%
data = pd.read_json('../../Data/Preprocessed Data/kind:bug/merged_data_with_comments.json')

# %%
data.head()
# Out:
#                                         comments_url          id  \
# 0  https://api.github.com/repos/kubernetes/kubern...  2639668210
# 1  https://api.github.com/repos/kubernetes/kubern...  2617512099
# 2  https://api.github.com/repos/kubernetes/kubern...  2604613192
# 3  https://api.github.com/repos/kubernetes/kubern...  2596132738
# 4  https://api.github.com/repos/kubernetes/kubern...  2591358936
#
#                                                title  \
# 0  kubelet crash: fatal error: concurrent map writes
# 1  [FG:InPlacePodVerticalScaling] failed to verif...
# 2          Restore build-tag flag for code-generator
# 3  [Failing Tests] ci-crio-cgroupv1-node-e2e-conf...
# 4  Crash on kube manager's service-lb-controller ...
#
#                                                 body  \
# 0  ### What happened?\n\nWhile looking into three...
# 1  ### What happened?\n\nOne line bug description...
# 2  ### What happened?\n\nThe `build-tag` flag is ...
# 3  ### Which jobs are failing?\n* master-blocking...
# 4  ### What happened?\n\nIf kube manager is start...
#
#                                            issue_url  \
# 0  https://github.com/kubernetes/kubernetes/issue...
# 1  https://github.com/kubernetes/kubernetes/issue...
# 2  https://github.com/kubernetes/kubernetes/issue...
# 3  https://github.com/kubernetes/kubernetes/issue...
# 4  https://github.com/kubernetes/kubernetes/issue...
#
#                                               pr_url  \
# 0  https://github.com/kubernetes/kubernetes/pull/...
# 1  https://github.com/kubernetes/kubernetes/pull/...
# 2  https://github.com/kubernetes/kubernetes/pull/...
# 3  https://github.com/kubernetes/kubernetes/pull/...
# 4  https://github.com/kubernetes/kubernetes/pull/...
#
#                             labels  pr_number  \
# 0                   [area/kubelet]     128657
# 1                   [area/kubelet]     126620
# 2           [area/code-generation]     128259
# 3  [area/kubeadm, area/dependency]     128175
# 4             [area/cloudprovider]     128182
#
#                                             filename  \
# 0  ['pkg/kubelet/cm/container_manager_linux.go', ...
# 1  ['pkg/kubelet/status/state/checkpoint.go', 'pk...
# 2  ['staging/src/k8s.io/code-generator/cmd/conver...
# 3  ['go.mod', 'go.sum', 'hack/unwanted-dependenci...
# 4  ['cmd/kube-controller-manager/app/controllerma...
#
#                                               status  \
# 0   ['modified', 'modified', 'modified', 'modified']
# 1                  ['modified', 'modified', 'added']
# 2  ['modified', 'modified', 'modified', 'modified...
# 3  ['modified', 'modified', 'modified', 'modified...
# 4               ['modified', 'modified', 'modified']
#
#                                       additions  \
# 0                                [3, 4, 18, 75]
# 1                                 [42, 23, 166]
# 2                          [12, 1, 1, 12, 1, 1]
# 3  [1, 3, 1, 21, 9, 9, 4, 0, 10, 2, 2, 5, 8, 1]
# 4                                   [26, 12, 5]
#
#                                         deletions  \
# 0                                    [3, 3, 6, 0]
# 1                                     [26, 17, 0]
# 2                              [2, 1, 1, 1, 1, 1]
# 3  [1, 2, 0, 98, 8, 7, 6, 62, 11, 1, 4, 8, 11, 1]
# 4                                       [0, 1, 4]
#
#                                              changes  \
# 0                                     [6, 7, 24, 75]
# 1                                      [68, 40, 166]
# 2                               [14, 2, 2, 13, 2, 2]
# 3  [2, 5, 1, 119, 17, 16, 10, 62, 21, 3, 6, 13, 1...
# 4                                        [26, 13, 9]
#
#                                         all_comments
# 0  /sig node Thought to search for similar errors...
# 1  This issue is currently awaiting triage.\n\nIf...
# 2  @p0lyn0mial FYI /sig api-machinery /triage acc...
# 3  @drewhagen: The provided milestone is not vali...
# 4  This issue is currently awaiting triage.\n\nIf...

# %% [markdown]
# # Text Preprocessing

# %% [markdown]
# Merge Title, Description, and Comments

# %%
# make new column with title, body, and comments all together
data['all_text'] = data['title'] + ' ' + data['body']

# %% [markdown]
# Lowercasing

# %%
# lowercase everything
data['all_text'] = data['all_text'].str.lower()
data['all_comments'] = data['all_comments'].str.lower()

# %% [markdown]
# Line break removal

# %%
# remove line breaks (\r, \n)
data['all_text'] = data['all_text'].str.replace('\r', ' ')
data['all_text'] = data['all_text'].str.replace('\n', ' ')
data['all_comments'] = data['all_comments'].str.replace('\r', ' ')
data['all_comments'] = data['all_comments'].str.replace('\n', ' ')

# %% [markdown]
# Remove Non-alphanumeric character

# %%
# remove non-alphanumeric characters such as punctuation, symbols, emojis, etc.
data['all_text'] = data['all_text'].str.replace(r'[^a-zA-Z0-9 ]', '')
data['all_comments'] = data['all_comments'].str.replace(r'[^a-zA-Z0-9 ]', '')

# %% [markdown]
# Change the datatype to string

# %%
# change datatype to string
data['all_text'] = data['all_text'].astype(str)
data['all_comments'] = data['all_comments'].astype(str)

# %% [markdown]
# Stopwords Removal

# %%
# remove stopwords using spaCy
try:
    nlp = spacy.load('en_core_web_sm')
except OSError:
    download('en_core_web_sm')
    nlp = spacy.load('en_core_web_sm')

data['all_text'] = data['all_text'].apply(lambda x: ' '.join([word.text for word in nlp(x) if not word.is_stop]))
data['all_comments'] = data['all_comments'].apply(lambda x: ' '.join([word.text for word in nlp(x) if not word.is_stop]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 8
#       5     download('en_core_web_sm')
#       6     nlp = spacy.load('en_core_web_sm')
# ----> 8 data['all_text'] = data['all_text'].apply(lambda x: ' '.join([word.text for word in nlp(x) if not word.is_stop]))
#       9 data['all_comments'] = data['all_comments'].apply(lambda x: ' '.join([word.text for word in nlp(x) if not word.is_stop]))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[19], line 8, in <lambda>(x)
#       5     download('en_core_web_sm')
#       6     nlp = spacy.load('en_core_web_sm')
# ----> 8 data['all_text'] = data['all_text'].apply(lambda x: ' '.join([word.text for word in nlp(x) if not word.is_stop]))
#       9 data['all_comments'] = data['all_comments'].apply(lambda x: ' '.join([word.text for word in nlp(x) if not word.is_stop]))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spacy/language.py:1052, in Language.__call__(self, text, disable, component_cfg)
#    1050     error_handler = proc.get_error_handler()
#    1051 try:
# -> 1052     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1053 except KeyError as e:
#    1054     # This typically happens if a component is not initialized
#    1055     raise ValueError(Errors.E109.format(name=name)) from e
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spacy/pipeline/trainable_pipe.pyx:52, in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spacy/pipeline/transition_parser.pyx:264, in spacy.pipeline.transition_parser.Parser.predict()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spacy/pipeline/transition_parser.pyx:285, in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/model.py:334, in Model.predict(self, X)
#     330 def predict(self, X: InT) -> OutT:
#     331     """Call the model's `forward` function with `is_train=False`, and return
#     332     only the output, instead of the `(output, callback)` tuple.
#     333     """
# --> 334     return self._func(self, X, is_train=False)[0]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spacy/ml/tb_framework.py:34, in forward(model, X, is_train)
#      33 def forward(model, X, is_train):
# ---> 34     step_model = ParserStepModel(
#      35         X,
#      36         model.layers,
#      37         unseen_classes=model.attrs["unseen_classes"],
#      38         train=is_train,
#      39         has_upper=model.attrs["has_upper"],
#      40     )
#      42     return step_model, step_model.finish_steps
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spacy/ml/parser_model.pyx:250, in spacy.ml.parser_model.ParserStepModel.__init__()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/layers/chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/layers/chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/layers/with_array.py:42, in forward(model, Xseq, is_train)
#      40     return model.layers[0](Xseq, is_train)
#      41 else:
# ---> 42     return cast(Tuple[SeqT, Callable], _list_forward(model, Xseq, is_train))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/layers/with_array.py:77, in _list_forward(model, Xs, is_train)
#      75 lengths = NUMPY_OPS.asarray1i([len(seq) for seq in Xs])
#      76 Xf = layer.ops.flatten(Xs, pad=pad)
# ---> 77 Yf, get_dXf = layer(Xf, is_train)
#      79 def backprop(dYs: ListXd) -> ListXd:
#      80     dYf = layer.ops.flatten(dYs, pad=pad)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/layers/chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/layers/residual.py:41, in forward(model, X, is_train)
#      38     else:
#      39         return d_output + dX
# ---> 41 Y, backprop_layer = model.layers[0](X, is_train)
#      42 if isinstance(X, list):
#      43     return [X[i] + Y[i] for i in range(len(X))], backprop
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/layers/chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/layers/chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
#     [... skipping similar frames: Model.__call__ at line 310 (1 times)]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/layers/chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/thinc/layers/maxout.py:52, in forward(model, X, is_train)
#      50 W = model.get_param("W")
#      51 W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 52 Y = model.ops.gemm(X, W, trans2=True)
#      53 Y += model.ops.reshape1f(b, nO * nP)
#      54 Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:

# %% [markdown]
# Data Lemmatization

# %%
# lematize the text using spaCy
data['all_text'] = data['all_text'].apply(lambda x: ' '.join([word.lemma_ for word in nlp(x)]))
data['all_comments'] = data['all_comments'].apply(lambda x: ' '.join([word.lemma_ for word in nlp(x)]))

# %% [markdown]
# Remove High Frequency Words

# %%
# Remove high frequency words with different thresholds
thresholds = [0.5, 0.6, 0.7, 0.8, 0.9]

for threshold in thresholds:
    print(f"Processing with threshold: {threshold}")
    
    # Create and fit CountVectorizer
    cv = CountVectorizer(max_df=threshold)
    cv.fit(data['all_text'])
    
    # Get vocabulary from fitted vectorizer
    vocabulary = cv.vocabulary_
    
    # Filter each document to only keep words in the vocabulary
    filtered_texts = []
    for text in data['all_text']:
        words = text.split()
        filtered_words = [word for word in words if word in vocabulary]
        filtered_texts.append(' '.join(filtered_words))
    
    # Store filtered texts in new column
    data['all_text_' + str(threshold)] = filtered_texts
    
    # Print statistics
    print(f"  Vocabulary size: {len(vocabulary)}")
    print(f"  Average words per document: {sum(len(text.split()) for text in filtered_texts) / len(filtered_texts):.2f}")
# Out:
# Processing with threshold: 0.5
#   Vocabulary size: 26632
#   Average words per document: 160.55
# Processing with threshold: 0.6
#   Vocabulary size: 26641
#   Average words per document: 164.91
# Processing with threshold: 0.7
#   Vocabulary size: 26652
#   Average words per document: 174.07
# Processing with threshold: 0.8
#   Vocabulary size: 26659
#   Average words per document: 178.25
# Processing with threshold: 0.9
#   Vocabulary size: 26664
#   Average words per document: 188.45

# %%
threshold = 0.3

# Create and fit CountVectorizer
cv = CountVectorizer(max_df=threshold)
cv.fit(data['all_comments'])

# Get vocabulary from fitted vectorizer
vocabulary = cv.vocabulary_

# Filter each document to only keep words in the vocabulary
filtered_texts = []
for text in data['all_comments']:
    words = text.split()
    filtered_words = [word for word in words if word in vocabulary]
    filtered_texts.append(' '.join(filtered_words))

# Store filtered texts in new column
data['all_comments_' + str(threshold)] = filtered_texts

# Print statistics
print(f"  Vocabulary size: {len(vocabulary)}")
print(f"  Average words per document: {sum(len(text.split()) for text in filtered_texts) / len(filtered_texts):.2f}")
# Out:
#   Vocabulary size: 28002
#   Average words per document: 191.64

# %% [markdown]
# Remove comments_url, id, title, body, issue_url, pr_url, and all_comments

# %%
data.head(5)
# Out:
#                                         comments_url          id  \
# 0  https://api.github.com/repos/kubernetes/kubern...  2639668210
# 1  https://api.github.com/repos/kubernetes/kubern...  2617512099
# 2  https://api.github.com/repos/kubernetes/kubern...  2604613192
# 3  https://api.github.com/repos/kubernetes/kubern...  2596132738
# 4  https://api.github.com/repos/kubernetes/kubern...  2591358936
#
#                                                title  \
# 0  kubelet crash: fatal error: concurrent map writes
# 1  [FG:InPlacePodVerticalScaling] failed to verif...
# 2          Restore build-tag flag for code-generator
# 3  [Failing Tests] ci-crio-cgroupv1-node-e2e-conf...
# 4  Crash on kube manager's service-lb-controller ...
#
#                                                 body  \
# 0  ### What happened?\n\nWhile looking into three...
# 1  ### What happened?\n\nOne line bug description...
# 2  ### What happened?\n\nThe `build-tag` flag is ...
# 3  ### Which jobs are failing?\n* master-blocking...
# 4  ### What happened?\n\nIf kube manager is start...
#
#                                            issue_url  \
# 0  https://github.com/kubernetes/kubernetes/issue...
# 1  https://github.com/kubernetes/kubernetes/issue...
# 2  https://github.com/kubernetes/kubernetes/issue...
# 3  https://github.com/kubernetes/kubernetes/issue...
# 4  https://github.com/kubernetes/kubernetes/issue...
#
#                                               pr_url  \
# 0  https://github.com/kubernetes/kubernetes/pull/...
# 1  https://github.com/kubernetes/kubernetes/pull/...
# 2  https://github.com/kubernetes/kubernetes/pull/...
# 3  https://github.com/kubernetes/kubernetes/pull/...
# 4  https://github.com/kubernetes/kubernetes/pull/...
#
#                             labels  pr_number  \
# 0                   [area/kubelet]     128657
# 1                   [area/kubelet]     126620
# 2           [area/code-generation]     128259
# 3  [area/kubeadm, area/dependency]     128175
# 4             [area/cloudprovider]     128182
#
#                                             filename  \
# 0  ['pkg/kubelet/cm/container_manager_linux.go', ...
# 1  ['pkg/kubelet/status/state/checkpoint.go', 'pk...
# 2  ['staging/src/k8s.io/code-generator/cmd/conver...
# 3  ['go.mod', 'go.sum', 'hack/unwanted-dependenci...
# 4  ['cmd/kube-controller-manager/app/controllerma...
#
#                                               status  \
# 0   ['modified', 'modified', 'modified', 'modified']
# 1                  ['modified', 'modified', 'added']
# 2  ['modified', 'modified', 'modified', 'modified...
# 3  ['modified', 'modified', 'modified', 'modified...
# 4               ['modified', 'modified', 'modified']
#
#                                       additions  \
# 0                                [3, 4, 18, 75]
# 1                                 [42, 23, 166]
# 2                          [12, 1, 1, 12, 1, 1]
# 3  [1, 3, 1, 21, 9, 9, 4, 0, 10, 2, 2, 5, 8, 1]
# 4                                   [26, 12, 5]
#
#                                         deletions  \
# 0                                    [3, 3, 6, 0]
# 1                                     [26, 17, 0]
# 2                              [2, 1, 1, 1, 1, 1]
# 3  [1, 2, 0, 98, 8, 7, 6, 62, 11, 1, 4, 8, 11, 1]
# 4                                       [0, 1, 4]
#
#                                              changes  \
# 0                                     [6, 7, 24, 75]
# 1                                      [68, 40, 166]
# 2                               [14, 2, 2, 13, 2, 2]
# 3  [2, 5, 1, 119, 17, 16, 10, 62, 21, 3, 6, 13, 1...
# 4                                        [26, 13, 9]
#
#                                         all_comments  \
# 0  /sig node thought search similar error example...
# 1  issue currently await triage .    sig subproje...
# 2  @p0lyn0mial fyi /sig api - machinery /triage a...
# 3  @drewhagen : provide milestone valid repositor...
# 4  issue currently await triage .    sig subproje...
#
#                                             all_text  \
# 0  kubelet crash : fatal error : concurrent map w...
# 1  [ fg : inplacepodverticalscale ] fail verify p...
# 2  restore build - tag flag code - generator # # ...
# 3  [ fail test ] ci-crio-cgroupv1-node-e2e-confor...
# 4  crash kube manager service - lb - controller v...
#
#                                         all_text_0.5  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.6  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.7  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.8  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.9
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator happen b...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller happe...

# %%
# remove columns that are not needed
data = data.drop(columns=['comments_url','id','title', 'body', 'issue_url','pr_url','all_comments','pr_number'])

# %% [markdown]
# Add filename to the text

# %%
# add filename to the data
for column_name in data.columns:
    if 'all_text' in column_name:
        data[column_name] = data[column_name] + ' ' + data['all_comments_0.3']
        data[column_name] = data[column_name] + ' ' + data['filename']

# %% [markdown]
# # Export the Data

# %%
data.head()
# Out:
#                             labels  \
# 0                   [area/kubelet]
# 1                   [area/kubelet]
# 2           [area/code-generation]
# 3  [area/kubeadm, area/dependency]
# 4             [area/cloudprovider]
#
#                                             filename  \
# 0  ['pkg/kubelet/cm/container_manager_linux.go', ...
# 1  ['pkg/kubelet/status/state/checkpoint.go', 'pk...
# 2  ['staging/src/k8s.io/code-generator/cmd/conver...
# 3  ['go.mod', 'go.sum', 'hack/unwanted-dependenci...
# 4  ['cmd/kube-controller-manager/app/controllerma...
#
#                                               status  \
# 0   ['modified', 'modified', 'modified', 'modified']
# 1                  ['modified', 'modified', 'added']
# 2  ['modified', 'modified', 'modified', 'modified...
# 3  ['modified', 'modified', 'modified', 'modified...
# 4               ['modified', 'modified', 'modified']
#
#                                       additions  \
# 0                                [3, 4, 18, 75]
# 1                                 [42, 23, 166]
# 2                          [12, 1, 1, 12, 1, 1]
# 3  [1, 3, 1, 21, 9, 9, 4, 0, 10, 2, 2, 5, 8, 1]
# 4                                   [26, 12, 5]
#
#                                         deletions  \
# 0                                    [3, 3, 6, 0]
# 1                                     [26, 17, 0]
# 2                              [2, 1, 1, 1, 1, 1]
# 3  [1, 2, 0, 98, 8, 7, 6, 62, 11, 1, 4, 8, 11, 1]
# 4                                       [0, 1, 4]
#
#                                              changes  \
# 0                                     [6, 7, 24, 75]
# 1                                      [68, 40, 166]
# 2                               [14, 2, 2, 13, 2, 2]
# 3  [2, 5, 1, 119, 17, 16, 10, 62, 21, 3, 6, 13, 1...
# 4                                        [26, 13, 9]
#
#                                             all_text  \
# 0  kubelet crash : fatal error : concurrent map w...
# 1  [ fg : inplacepodverticalscale ] fail verify p...
# 2  restore build - tag flag code - generator # # ...
# 3  [ fail test ] ci-crio-cgroupv1-node-e2e-confor...
# 4  crash kube manager service - lb - controller v...
#
#                                         all_text_0.5  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.6  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.7  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.8  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.9  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator happen b...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller happe...
#
#                                     all_comments_0.3
# 0  thought search similar error example crash fin...
# 1  currently await subproject determine relevant ...
# 2                                      fyi machinery
# 3  provide milestone valid milestone candidate us...
# 4  currently await subproject determine relevant ...

# %%
# swap the order of the columns
data = data[['all_text','all_text_0.5','all_text_0.6','all_text_0.7','all_text_0.8','all_text_0.9','labels','filename','status','additions','deletions','changes', 'all_comments_0.3']]

# %%
data.head()
# Out:
#                                             all_text  \
# 0  kubelet crash : fatal error : concurrent map w...
# 1  [ fg : inplacepodverticalscale ] fail verify p...
# 2  restore build - tag flag code - generator # # ...
# 3  [ fail test ] ci-crio-cgroupv1-node-e2e-confor...
# 4  crash kube manager service - lb - controller v...
#
#                                         all_text_0.5  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.6  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.7  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.8  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.9  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator happen b...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller happe...
#
#                             labels  \
# 0                   [area/kubelet]
# 1                   [area/kubelet]
# 2           [area/code-generation]
# 3  [area/kubeadm, area/dependency]
# 4             [area/cloudprovider]
#
#                                             filename  \
# 0  ['pkg/kubelet/cm/container_manager_linux.go', ...
# 1  ['pkg/kubelet/status/state/checkpoint.go', 'pk...
# 2  ['staging/src/k8s.io/code-generator/cmd/conver...
# 3  ['go.mod', 'go.sum', 'hack/unwanted-dependenci...
# 4  ['cmd/kube-controller-manager/app/controllerma...
#
#                                               status  \
# 0   ['modified', 'modified', 'modified', 'modified']
# 1                  ['modified', 'modified', 'added']
# 2  ['modified', 'modified', 'modified', 'modified...
# 3  ['modified', 'modified', 'modified', 'modified...
# 4               ['modified', 'modified', 'modified']
#
#                                       additions  \
# 0                                [3, 4, 18, 75]
# 1                                 [42, 23, 166]
# 2                          [12, 1, 1, 12, 1, 1]
# 3  [1, 3, 1, 21, 9, 9, 4, 0, 10, 2, 2, 5, 8, 1]
# 4                                   [26, 12, 5]
#
#                                         deletions  \
# 0                                    [3, 3, 6, 0]
# 1                                     [26, 17, 0]
# 2                              [2, 1, 1, 1, 1, 1]
# 3  [1, 2, 0, 98, 8, 7, 6, 62, 11, 1, 4, 8, 11, 1]
# 4                                       [0, 1, 4]
#
#                                              changes  \
# 0                                     [6, 7, 24, 75]
# 1                                      [68, 40, 166]
# 2                               [14, 2, 2, 13, 2, 2]
# 3  [2, 5, 1, 119, 17, 16, 10, 62, 21, 3, 6, 13, 1...
# 4                                        [26, 13, 9]
#
#                                     all_comments_0.3
# 0  thought search similar error example crash fin...
# 1  currently await subproject determine relevant ...
# 2                                      fyi machinery
# 3  provide milestone valid milestone candidate us...
# 4  currently await subproject determine relevant ...

# %%
# export cleaned data 
data.to_json('../../Data/Preprocessed Data/kind:bug/cleaned_data_with_changed_files_reduced_comments.json')

# %%
data.head()
# Out:
#                                             all_text  \
# 0  kubelet crash : fatal error : concurrent map w...
# 1  [ fg : inplacepodverticalscale ] fail verify p...
# 2  restore build - tag flag code - generator # # ...
# 3  [ fail test ] ci-crio-cgroupv1-node-e2e-confor...
# 4  crash kube manager service - lb - controller v...
#
#                                         all_text_0.5  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.6  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.7  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.8  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.9  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator happen b...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller happe...
#
#                             labels  \
# 0                   [area/kubelet]
# 1                   [area/kubelet]
# 2           [area/code-generation]
# 3  [area/kubeadm, area/dependency]
# 4             [area/cloudprovider]
#
#                                             filename  \
# 0  ['pkg/kubelet/cm/container_manager_linux.go', ...
# 1  ['pkg/kubelet/status/state/checkpoint.go', 'pk...
# 2  ['staging/src/k8s.io/code-generator/cmd/conver...
# 3  ['go.mod', 'go.sum', 'hack/unwanted-dependenci...
# 4  ['cmd/kube-controller-manager/app/controllerma...
#
#                                               status  \
# 0   ['modified', 'modified', 'modified', 'modified']
# 1                  ['modified', 'modified', 'added']
# 2  ['modified', 'modified', 'modified', 'modified...
# 3  ['modified', 'modified', 'modified', 'modified...
# 4               ['modified', 'modified', 'modified']
#
#                                       additions  \
# 0                                [3, 4, 18, 75]
# 1                                 [42, 23, 166]
# 2                          [12, 1, 1, 12, 1, 1]
# 3  [1, 3, 1, 21, 9, 9, 4, 0, 10, 2, 2, 5, 8, 1]
# 4                                   [26, 12, 5]
#
#                                         deletions  \
# 0                                    [3, 3, 6, 0]
# 1                                     [26, 17, 0]
# 2                              [2, 1, 1, 1, 1, 1]
# 3  [1, 2, 0, 98, 8, 7, 6, 62, 11, 1, 4, 8, 11, 1]
# 4                                       [0, 1, 4]
#
#                                              changes  \
# 0                                     [6, 7, 24, 75]
# 1                                      [68, 40, 166]
# 2                               [14, 2, 2, 13, 2, 2]
# 3  [2, 5, 1, 119, 17, 16, 10, 62, 21, 3, 6, 13, 1...
# 4                                        [26, 13, 9]
#
#                                     all_comments_0.3
# 0  thought search similar error example crash fin...
# 1  currently await subproject determine relevant ...
# 2                                      fyi machinery
# 3  provide milestone valid milestone candidate us...
# 4  currently await subproject determine relevant ...
