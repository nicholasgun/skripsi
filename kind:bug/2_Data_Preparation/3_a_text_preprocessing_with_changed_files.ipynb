# %%
import pandas as pd
from spacy.cli import download
from sklearn.feature_extraction.text import CountVectorizer
import spacy

# %%
data = pd.read_json('../../Data/Preprocessed Data/kind:bug/merged_data_with_comments.json')

# %%
data.head()
# Out:
#                                         comments_url          id  \
# 0  https://api.github.com/repos/kubernetes/kubern...  2639668210
# 1  https://api.github.com/repos/kubernetes/kubern...  2617512099
# 2  https://api.github.com/repos/kubernetes/kubern...  2604613192
# 3  https://api.github.com/repos/kubernetes/kubern...  2596132738
# 4  https://api.github.com/repos/kubernetes/kubern...  2591358936
#
#                                                title  \
# 0  kubelet crash: fatal error: concurrent map writes
# 1  [FG:InPlacePodVerticalScaling] failed to verif...
# 2          Restore build-tag flag for code-generator
# 3  [Failing Tests] ci-crio-cgroupv1-node-e2e-conf...
# 4  Crash on kube manager's service-lb-controller ...
#
#                                                 body  \
# 0  ### What happened?\n\nWhile looking into three...
# 1  ### What happened?\n\nOne line bug description...
# 2  ### What happened?\n\nThe `build-tag` flag is ...
# 3  ### Which jobs are failing?\n* master-blocking...
# 4  ### What happened?\n\nIf kube manager is start...
#
#                                            issue_url  \
# 0  https://github.com/kubernetes/kubernetes/issue...
# 1  https://github.com/kubernetes/kubernetes/issue...
# 2  https://github.com/kubernetes/kubernetes/issue...
# 3  https://github.com/kubernetes/kubernetes/issue...
# 4  https://github.com/kubernetes/kubernetes/issue...
#
#                                               pr_url  \
# 0  https://github.com/kubernetes/kubernetes/pull/...
# 1  https://github.com/kubernetes/kubernetes/pull/...
# 2  https://github.com/kubernetes/kubernetes/pull/...
# 3  https://github.com/kubernetes/kubernetes/pull/...
# 4  https://github.com/kubernetes/kubernetes/pull/...
#
#                             labels  pr_number  \
# 0                   [area/kubelet]     128657
# 1                   [area/kubelet]     126620
# 2           [area/code-generation]     128259
# 3  [area/kubeadm, area/dependency]     128175
# 4             [area/cloudprovider]     128182
#
#                                             filename  \
# 0  ['pkg/kubelet/cm/container_manager_linux.go', ...
# 1  ['pkg/kubelet/status/state/checkpoint.go', 'pk...
# 2  ['staging/src/k8s.io/code-generator/cmd/conver...
# 3  ['go.mod', 'go.sum', 'hack/unwanted-dependenci...
# 4  ['cmd/kube-controller-manager/app/controllerma...
#
#                                               status  \
# 0   ['modified', 'modified', 'modified', 'modified']
# 1                  ['modified', 'modified', 'added']
# 2  ['modified', 'modified', 'modified', 'modified...
# 3  ['modified', 'modified', 'modified', 'modified...
# 4               ['modified', 'modified', 'modified']
#
#                                       additions  \
# 0                                [3, 4, 18, 75]
# 1                                 [42, 23, 166]
# 2                          [12, 1, 1, 12, 1, 1]
# 3  [1, 3, 1, 21, 9, 9, 4, 0, 10, 2, 2, 5, 8, 1]
# 4                                   [26, 12, 5]
#
#                                         deletions  \
# 0                                    [3, 3, 6, 0]
# 1                                     [26, 17, 0]
# 2                              [2, 1, 1, 1, 1, 1]
# 3  [1, 2, 0, 98, 8, 7, 6, 62, 11, 1, 4, 8, 11, 1]
# 4                                       [0, 1, 4]
#
#                                              changes  \
# 0                                     [6, 7, 24, 75]
# 1                                      [68, 40, 166]
# 2                               [14, 2, 2, 13, 2, 2]
# 3  [2, 5, 1, 119, 17, 16, 10, 62, 21, 3, 6, 13, 1...
# 4                                        [26, 13, 9]
#
#                                         all_comments
# 0  /sig node Thought to search for similar errors...
# 1  This issue is currently awaiting triage.\n\nIf...
# 2  @p0lyn0mial FYI /sig api-machinery /triage acc...
# 3  @drewhagen: The provided milestone is not vali...
# 4  This issue is currently awaiting triage.\n\nIf...

# %% [markdown]
# # Text Preprocessing

# %% [markdown]
# Merge Title, Description, and Comments

# %%
# make new column with title, body, and comments all together
# data['all_text'] = data['title'] + ' ' + data['body'] + ' ' + data['all_comments']
data['all_text'] = data['title'] + ' ' + data['body']

# %% [markdown]
# Lowercasing

# %%
# lowercase everything
data['all_text'] = data['all_text'].str.lower()

# %% [markdown]
# Line break removal

# %%
# remove line breaks (\r, \n)
data['all_text'] = data['all_text'].str.replace('\r', ' ')
data['all_text'] = data['all_text'].str.replace('\n', ' ')

# %% [markdown]
# Remove Non-alphanumeric character

# %%
# remove non-alphanumeric characters such as punctuation, symbols, emojis, etc.
data['all_text'] = data['all_text'].str.replace(r'[^a-zA-Z0-9 ]', '')

# %% [markdown]
# Change the datatype to string

# %%
# change datatype to string
data['all_text'] = data['all_text'].astype(str)

# %% [markdown]
# Stopwords Removal

# %%
# remove stopwords using spaCy
try:
    nlp = spacy.load('en_core_web_sm')
except OSError:
    download('en_core_web_sm')
    nlp = spacy.load('en_core_web_sm')

data['all_text'] = data['all_text'].apply(lambda x: ' '.join([word.text for word in nlp(x) if not word.is_stop]))

# %% [markdown]
# Data Lemmatization

# %%
# lematize the text using spaCy
data['all_text'] = data['all_text'].apply(lambda x: ' '.join([word.lemma_ for word in nlp(x)]))

# %% [markdown]
# Remove High Frequency Words

# %%
# Remove high frequency words with different thresholds
thresholds = [0.5, 0.6, 0.7, 0.8, 0.9]

for threshold in thresholds:
    print(f"Processing with threshold: {threshold}")
    
    # Create and fit CountVectorizer
    cv = CountVectorizer(max_df=threshold)
    cv.fit(data['all_text'])
    
    # Get vocabulary from fitted vectorizer
    vocabulary = cv.vocabulary_
    
    # Filter each document to only keep words in the vocabulary
    filtered_texts = []
    for text in data['all_text']:
        words = text.split()
        filtered_words = [word for word in words if word in vocabulary]
        filtered_texts.append(' '.join(filtered_words))
    
    # Store filtered texts in new column
    data['all_text_' + str(threshold)] = filtered_texts
    
    # Print statistics
    print(f"  Vocabulary size: {len(vocabulary)}")
    print(f"  Average words per document: {sum(len(text.split()) for text in filtered_texts) / len(filtered_texts):.2f}")
# Out:
# Processing with threshold: 0.5
#   Vocabulary size: 26632
#   Average words per document: 160.55
# Processing with threshold: 0.6
#   Vocabulary size: 26641
#   Average words per document: 164.91
# Processing with threshold: 0.7
#   Vocabulary size: 26652
#   Average words per document: 174.07
# Processing with threshold: 0.8
#   Vocabulary size: 26659
#   Average words per document: 178.25
# Processing with threshold: 0.9
#   Vocabulary size: 26664
#   Average words per document: 188.45

# %% [markdown]
# Remove comments_url, id, title, body, issue_url, pr_url, and all_comments

# %%
data.head(5)
# Out:
#                                         comments_url          id  \
# 0  https://api.github.com/repos/kubernetes/kubern...  2639668210
# 1  https://api.github.com/repos/kubernetes/kubern...  2617512099
# 2  https://api.github.com/repos/kubernetes/kubern...  2604613192
# 3  https://api.github.com/repos/kubernetes/kubern...  2596132738
# 4  https://api.github.com/repos/kubernetes/kubern...  2591358936
#
#                                                title  \
# 0  kubelet crash: fatal error: concurrent map writes
# 1  [FG:InPlacePodVerticalScaling] failed to verif...
# 2          Restore build-tag flag for code-generator
# 3  [Failing Tests] ci-crio-cgroupv1-node-e2e-conf...
# 4  Crash on kube manager's service-lb-controller ...
#
#                                                 body  \
# 0  ### What happened?\n\nWhile looking into three...
# 1  ### What happened?\n\nOne line bug description...
# 2  ### What happened?\n\nThe `build-tag` flag is ...
# 3  ### Which jobs are failing?\n* master-blocking...
# 4  ### What happened?\n\nIf kube manager is start...
#
#                                            issue_url  \
# 0  https://github.com/kubernetes/kubernetes/issue...
# 1  https://github.com/kubernetes/kubernetes/issue...
# 2  https://github.com/kubernetes/kubernetes/issue...
# 3  https://github.com/kubernetes/kubernetes/issue...
# 4  https://github.com/kubernetes/kubernetes/issue...
#
#                                               pr_url  \
# 0  https://github.com/kubernetes/kubernetes/pull/...
# 1  https://github.com/kubernetes/kubernetes/pull/...
# 2  https://github.com/kubernetes/kubernetes/pull/...
# 3  https://github.com/kubernetes/kubernetes/pull/...
# 4  https://github.com/kubernetes/kubernetes/pull/...
#
#                             labels  pr_number  \
# 0                   [area/kubelet]     128657
# 1                   [area/kubelet]     126620
# 2           [area/code-generation]     128259
# 3  [area/kubeadm, area/dependency]     128175
# 4             [area/cloudprovider]     128182
#
#                                             filename  \
# 0  ['pkg/kubelet/cm/container_manager_linux.go', ...
# 1  ['pkg/kubelet/status/state/checkpoint.go', 'pk...
# 2  ['staging/src/k8s.io/code-generator/cmd/conver...
# 3  ['go.mod', 'go.sum', 'hack/unwanted-dependenci...
# 4  ['cmd/kube-controller-manager/app/controllerma...
#
#                                               status  \
# 0   ['modified', 'modified', 'modified', 'modified']
# 1                  ['modified', 'modified', 'added']
# 2  ['modified', 'modified', 'modified', 'modified...
# 3  ['modified', 'modified', 'modified', 'modified...
# 4               ['modified', 'modified', 'modified']
#
#                                       additions  \
# 0                                [3, 4, 18, 75]
# 1                                 [42, 23, 166]
# 2                          [12, 1, 1, 12, 1, 1]
# 3  [1, 3, 1, 21, 9, 9, 4, 0, 10, 2, 2, 5, 8, 1]
# 4                                   [26, 12, 5]
#
#                                         deletions  \
# 0                                    [3, 3, 6, 0]
# 1                                     [26, 17, 0]
# 2                              [2, 1, 1, 1, 1, 1]
# 3  [1, 2, 0, 98, 8, 7, 6, 62, 11, 1, 4, 8, 11, 1]
# 4                                       [0, 1, 4]
#
#                                              changes  \
# 0                                     [6, 7, 24, 75]
# 1                                      [68, 40, 166]
# 2                               [14, 2, 2, 13, 2, 2]
# 3  [2, 5, 1, 119, 17, 16, 10, 62, 21, 3, 6, 13, 1...
# 4                                        [26, 13, 9]
#
#                                         all_comments  \
# 0  /sig node Thought to search for similar errors...
# 1  This issue is currently awaiting triage.\n\nIf...
# 2  @p0lyn0mial FYI /sig api-machinery /triage acc...
# 3  @drewhagen: The provided milestone is not vali...
# 4  This issue is currently awaiting triage.\n\nIf...
#
#                                             all_text  \
# 0  kubelet crash : fatal error : concurrent map w...
# 1  [ fg : inplacepodverticalscale ] fail verify p...
# 2  restore build - tag flag code - generator # # ...
# 3  [ fail test ] ci-crio-cgroupv1-node-e2e-confor...
# 4  crash kube manager service - lb - controller v...
#
#                                         all_text_0.5  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.6  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.7  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.8  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.9
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator happen b...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller happe...

# %%
# remove columns that are not needed
data = data.drop(columns=['comments_url','id','title', 'body', 'issue_url','pr_url','all_comments','pr_number'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 2
#       1 # remove columns that are not needed
# ----> 2 data = data.drop(columns=['comments_url','id','title', 'body', 'issue_url','pr_url','all_comments','pr_number'])
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['comments_url', 'id', 'title', 'body', 'issue_url', 'pr_url', 'all_comments', 'pr_number'] not found in axis"

# %% [markdown]
# Add filename to the text

# %%
# add filename to the data
for column_name in data.columns:
    if 'all_text' in column_name:
        data[column_name] = data[column_name] + ' ' + data['filename']

# %% [markdown]
# # Export the Data

# %%
data.head()
# Out:
#                                         comments_url          id  \
# 0  https://api.github.com/repos/kubernetes/kubern...  2639668210
# 1  https://api.github.com/repos/kubernetes/kubern...  2617512099
# 2  https://api.github.com/repos/kubernetes/kubern...  2604613192
# 3  https://api.github.com/repos/kubernetes/kubern...  2596132738
# 4  https://api.github.com/repos/kubernetes/kubern...  2591358936
#
#                                                title  \
# 0  kubelet crash: fatal error: concurrent map writes
# 1  [FG:InPlacePodVerticalScaling] failed to verif...
# 2          Restore build-tag flag for code-generator
# 3  [Failing Tests] ci-crio-cgroupv1-node-e2e-conf...
# 4  Crash on kube manager's service-lb-controller ...
#
#                                                 body  \
# 0  ### What happened?\n\nWhile looking into three...
# 1  ### What happened?\n\nOne line bug description...
# 2  ### What happened?\n\nThe `build-tag` flag is ...
# 3  ### Which jobs are failing?\n* master-blocking...
# 4  ### What happened?\n\nIf kube manager is start...
#
#                                            issue_url  \
# 0  https://github.com/kubernetes/kubernetes/issue...
# 1  https://github.com/kubernetes/kubernetes/issue...
# 2  https://github.com/kubernetes/kubernetes/issue...
# 3  https://github.com/kubernetes/kubernetes/issue...
# 4  https://github.com/kubernetes/kubernetes/issue...
#
#                                               pr_url  \
# 0  https://github.com/kubernetes/kubernetes/pull/...
# 1  https://github.com/kubernetes/kubernetes/pull/...
# 2  https://github.com/kubernetes/kubernetes/pull/...
# 3  https://github.com/kubernetes/kubernetes/pull/...
# 4  https://github.com/kubernetes/kubernetes/pull/...
#
#                             labels  pr_number  \
# 0                   [area/kubelet]     128657
# 1                   [area/kubelet]     126620
# 2           [area/code-generation]     128259
# 3  [area/kubeadm, area/dependency]     128175
# 4             [area/cloudprovider]     128182
#
#                                             filename  \
# 0  ['pkg/kubelet/cm/container_manager_linux.go', ...
# 1  ['pkg/kubelet/status/state/checkpoint.go', 'pk...
# 2  ['staging/src/k8s.io/code-generator/cmd/conver...
# 3  ['go.mod', 'go.sum', 'hack/unwanted-dependenci...
# 4  ['cmd/kube-controller-manager/app/controllerma...
#
#                                               status  \
# 0   ['modified', 'modified', 'modified', 'modified']
# 1                  ['modified', 'modified', 'added']
# 2  ['modified', 'modified', 'modified', 'modified...
# 3  ['modified', 'modified', 'modified', 'modified...
# 4               ['modified', 'modified', 'modified']
#
#                                       additions  \
# 0                                [3, 4, 18, 75]
# 1                                 [42, 23, 166]
# 2                          [12, 1, 1, 12, 1, 1]
# 3  [1, 3, 1, 21, 9, 9, 4, 0, 10, 2, 2, 5, 8, 1]
# 4                                   [26, 12, 5]
#
#                                         deletions  \
# 0                                    [3, 3, 6, 0]
# 1                                     [26, 17, 0]
# 2                              [2, 1, 1, 1, 1, 1]
# 3  [1, 2, 0, 98, 8, 7, 6, 62, 11, 1, 4, 8, 11, 1]
# 4                                       [0, 1, 4]
#
#                                              changes  \
# 0                                     [6, 7, 24, 75]
# 1                                      [68, 40, 166]
# 2                               [14, 2, 2, 13, 2, 2]
# 3  [2, 5, 1, 119, 17, 16, 10, 62, 21, 3, 6, 13, 1...
# 4                                        [26, 13, 9]
#
#                                         all_comments  \
# 0  /sig node Thought to search for similar errors...
# 1  This issue is currently awaiting triage.\n\nIf...
# 2  @p0lyn0mial FYI /sig api-machinery /triage acc...
# 3  @drewhagen: The provided milestone is not vali...
# 4  This issue is currently awaiting triage.\n\nIf...
#
#                                             all_text  \
# 0  kubelet crash : fatal error : concurrent map w...
# 1  [ fg : inplacepodverticalscale ] fail verify p...
# 2  restore build - tag flag code - generator # # ...
# 3  [ fail test ] ci-crio-cgroupv1-node-e2e-confor...
# 4  crash kube manager service - lb - controller v...
#
#                                         all_text_0.5  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail impact multiple job job fail master block...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.6  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail impact multiple job job fail master block...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.7  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.8  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.9
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator happen b...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller happe...

# %%
# swap the order of the columns
data = data[['all_text','all_text_0.5', 'all_text_0.6', 'all_text_0.7', 'all_text_0.8', 'all_text_0.9', 'labels','filename','status','additions','deletions','changes']]

# %%
data.head()
# Out:
#                                             all_text  \
# 0  kubelet crash : fatal error : concurrent map w...
# 1  [ fg : inplacepodverticalscale ] fail verify p...
# 2  restore build - tag flag code - generator # # ...
# 3  [ fail test ] ci-crio-cgroupv1-node-e2e-confor...
# 4  crash kube manager service - lb - controller v...
#
#                                         all_text_0.5  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail impact multiple job job fail master block...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.6  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail impact multiple job job fail master block...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.7  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.8  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator build ta...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller kube ...
#
#                                         all_text_0.9  \
# 0  kubelet crash fatal error concurrent map write...
# 1  fg inplacepodverticalscale fail verify pod sta...
# 2  restore build tag flag code generator happen b...
# 3  fail test impact multiple job job fail master ...
# 4  crash kube manager service lb controller happe...
#
#                             labels  \
# 0                   [area/kubelet]
# 1                   [area/kubelet]
# 2           [area/code-generation]
# 3  [area/kubeadm, area/dependency]
# 4             [area/cloudprovider]
#
#                                             filename  \
# 0  ['pkg/kubelet/cm/container_manager_linux.go', ...
# 1  ['pkg/kubelet/status/state/checkpoint.go', 'pk...
# 2  ['staging/src/k8s.io/code-generator/cmd/conver...
# 3  ['go.mod', 'go.sum', 'hack/unwanted-dependenci...
# 4  ['cmd/kube-controller-manager/app/controllerma...
#
#                                               status  \
# 0   ['modified', 'modified', 'modified', 'modified']
# 1                  ['modified', 'modified', 'added']
# 2  ['modified', 'modified', 'modified', 'modified...
# 3  ['modified', 'modified', 'modified', 'modified...
# 4               ['modified', 'modified', 'modified']
#
#                                       additions  \
# 0                                [3, 4, 18, 75]
# 1                                 [42, 23, 166]
# 2                          [12, 1, 1, 12, 1, 1]
# 3  [1, 3, 1, 21, 9, 9, 4, 0, 10, 2, 2, 5, 8, 1]
# 4                                   [26, 12, 5]
#
#                                         deletions  \
# 0                                    [3, 3, 6, 0]
# 1                                     [26, 17, 0]
# 2                              [2, 1, 1, 1, 1, 1]
# 3  [1, 2, 0, 98, 8, 7, 6, 62, 11, 1, 4, 8, 11, 1]
# 4                                       [0, 1, 4]
#
#                                              changes
# 0                                     [6, 7, 24, 75]
# 1                                      [68, 40, 166]
# 2                               [14, 2, 2, 13, 2, 2]
# 3  [2, 5, 1, 119, 17, 16, 10, 62, 21, 3, 6, 13, 1...
# 4                                        [26, 13, 9]

# %%
data['all_text_0.5'][0]
# Out:
# 'kubelet crash fatal error concurrent map write look fail e2e test allalpha job find kubelet crash ci log log ci e2e gci gce alpha enable artifact bootstrap e2e minion group h288 nov 07 bootstrap e2e minion group h288 fatal error concurrent map write nov 07 bootstrap e2e minion group h288 goroutine 29497 run nov 07 bootstrap e2e minion group h288 nov 07 bootstrap e2e minion group h288 nov 07 bootstrap e2e minion group h288 0xc002175688 0xc002d8a780 0xc002d21ec0 0x40 nov 07 bootstrap e2e minion group h288 nov 07 bootstrap e2e minion group h288 0xc002175688 0xc002d8a780 0xc002d21ec0 0x40 nov 07 bootstrap e2e minion group h288 nov 07 bootstrap e2e minion group h288 0x334ff38 0xc001184050 0xc0017ab600 0x40 0xc000323420 0xc0026aad58 0xc002175688 0xc002856c60 0x4de4ae0 nov 07 bootstrap e2e minion group h288 nov 07 bootstrap e2e minion group h288 0xc001184050 0x2e91ac3 0x9 0x2e91ac3 0x9 0xc0026aad58 nov 07 bootstrap e2e minion group h288 nov 07 bootstrap e2e minion group h288 0x334ff38 0xc001184050 0xc002175688 0xc002856c60 0x4de4ae0 0x0 0x0 0xc00095f220 nov 07 bootstrap e2e minion group h288 nov 07 bootstrap e2e minion group h288 0x334ff00 0xc001133860 0x2 0xc002175688 0x0 0xc002856c60 nov 07 bootstrap e2e minion group h288 nov 07 bootstrap e2e minion group h288 0x2 0xc1c322abaa0c010a 0x7267b7d9ca 0x4dc1f60 0xc002175688 0x0 0x0 0x0 0xc000ad6960 nov 07 bootstrap e2e minion group h288 nov 07 bootstrap e2e minion group h288 0xc000e53bc0 0x24 0xc002574150 nov 07 bootstrap e2e minion group h288 nov 07 bootstrap e2e minion group h288 nov 07 bootstrap e2e minion group h288 nov 07 bootstrap e2e minion group h288 create goroutine 250 nov 07 bootstrap e2e minion group h288 crash log prow job encounter crash require particular alpha feature gate allalpha job response detail 4c487b00afb20b detail gce detail console linux paste output paste output window wmic caption buildnumber osarchitecture paste output detail container runtime cri applicable detail cni csi applicable detail'

# %%
# export cleaned data 
data.to_json('../../Data/Preprocessed Data/kind:bug/cleaned_data_with_changed_files.json')
