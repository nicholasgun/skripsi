# %%
import pandas as pd

# %%
# get the issues (read json file)
issues = pd.read_json('../../Data/Data From API/Kind:Bug/github_bug_issues.json')

# get the shape of the dataframe
print(issues.shape)
# Out:
# (13932, 30)

# %%
issues.head(5)
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/kubernetes/kubern...
# 1  https://api.github.com/repos/kubernetes/kubern...
# 2  https://api.github.com/repos/kubernetes/kubern...
# 3  https://api.github.com/repos/kubernetes/kubern...
# 4  https://api.github.com/repos/kubernetes/kubern...
#
#                                       repository_url  \
# 0  https://api.github.com/repos/kubernetes/kubern...
# 1  https://api.github.com/repos/kubernetes/kubern...
# 2  https://api.github.com/repos/kubernetes/kubern...
# 3  https://api.github.com/repos/kubernetes/kubern...
# 4  https://api.github.com/repos/kubernetes/kubern...
#
#                                           labels_url  \
# 0  https://api.github.com/repos/kubernetes/kubern...
# 1  https://api.github.com/repos/kubernetes/kubern...
# 2  https://api.github.com/repos/kubernetes/kubern...
# 3  https://api.github.com/repos/kubernetes/kubern...
# ...

# %%
# get the link between pr and issues
links = pd.read_json('../../Data/Data From API/Kind:Bug/pr_bug_links_new.json')

print(links.shape)
# Out:
# (3214, 2)

# %%
links.head(5)
# Out:
#                                            issue_url  \
# 0  https://github.com/d2iq-archive/kubernetes-mes...
# 1  https://github.com/d2iq-archive/kubernetes-mes...
# 2  https://github.com/d2iq-archive/kubernetes-mes...
# 3  https://github.com/kubernetes/kubernetes/issue...
# 4  https://github.com/kubernetes/kubernetes/issue...
#
#                                               pr_url
# 0  https://github.com/kubernetes/kubernetes/pull/...
# 1  https://github.com/kubernetes/kubernetes/pull/...
# 2  https://github.com/kubernetes/kubernetes/pull/...
# 3  https://github.com/kubernetes/kubernetes/pull/...
# 4  https://github.com/kubernetes/kubernetes/pull/...

# %%
# merge the issues and links
data = issues.merge(links, left_on='html_url', right_on='issue_url', how='inner')

# remove html_url column
data.drop(columns=['html_url'], inplace=True)

print(f'new shape: {data.shape}')
# Out:
# new shape: (2272, 31)

# %%
data.head(5)
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/kubernetes/kubern...
# 1  https://api.github.com/repos/kubernetes/kubern...
# 2  https://api.github.com/repos/kubernetes/kubern...
# 3  https://api.github.com/repos/kubernetes/kubern...
# 4  https://api.github.com/repos/kubernetes/kubern...
#
#                                       repository_url  \
# 0  https://api.github.com/repos/kubernetes/kubern...
# 1  https://api.github.com/repos/kubernetes/kubern...
# 2  https://api.github.com/repos/kubernetes/kubern...
# 3  https://api.github.com/repos/kubernetes/kubern...
# 4  https://api.github.com/repos/kubernetes/kubern...
#
#                                           labels_url  \
# 0  https://api.github.com/repos/kubernetes/kubern...
# 1  https://api.github.com/repos/kubernetes/kubern...
# 2  https://api.github.com/repos/kubernetes/kubern...
# 3  https://api.github.com/repos/kubernetes/kubern...
# ...

# %%
# leave the comments_url, id, title, body, issue_url, and pr_url columns
data = data[['comments_url', 'id', 'title', 'body', 'issue_url', 'pr_url']]
data.head(5)
# Out:
#                                         comments_url          id  \
# 0  https://api.github.com/repos/kubernetes/kubern...  2639668210
# 1  https://api.github.com/repos/kubernetes/kubern...  2617512099
# 2  https://api.github.com/repos/kubernetes/kubern...  2604613192
# 3  https://api.github.com/repos/kubernetes/kubern...  2596132738
# 4  https://api.github.com/repos/kubernetes/kubern...  2595110543
#
#                                                title  \
# 0  kubelet crash: fatal error: concurrent map writes
# 1  [FG:InPlacePodVerticalScaling] failed to verif...
# 2          Restore build-tag flag for code-generator
# 3  [Failing Tests] ci-crio-cgroupv1-node-e2e-conf...
# 4  [Bug] Missing constraint and validation for la...
#
#                                                 body  \
# 0  ### What happened?\n\nWhile looking into three...
# 1  ### What happened?\n\nOne line bug description...
# 2  ### What happened?\n\nThe `build-tag` flag is ...
# ...

# %%
# get the pr (read json file)
prs = pd.read_json('../../Data/Data From API/Kind:Bug/merged_pull_requests_with_label_kind_bug_2015_until_2025.json')
print(prs.shape)
# Out:
# (3109, 32)

# %%
prs.head(5)
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/kubernetes/kubern...
# 1  https://api.github.com/repos/kubernetes/kubern...
# 2  https://api.github.com/repos/kubernetes/kubern...
# 3  https://api.github.com/repos/kubernetes/kubern...
# 4  https://api.github.com/repos/kubernetes/kubern...
#
#                                       repository_url  \
# 0  https://api.github.com/repos/kubernetes/kubern...
# 1  https://api.github.com/repos/kubernetes/kubern...
# 2  https://api.github.com/repos/kubernetes/kubern...
# 3  https://api.github.com/repos/kubernetes/kubern...
# 4  https://api.github.com/repos/kubernetes/kubern...
#
#                                           labels_url  \
# 0  https://api.github.com/repos/kubernetes/kubern...
# 1  https://api.github.com/repos/kubernetes/kubern...
# 2  https://api.github.com/repos/kubernetes/kubern...
# 3  https://api.github.com/repos/kubernetes/kubern...
# ...

# %%
# only leaves the html_url, labels, and pr number
prs = prs[['html_url', 'labels', 'number']]
prs.head(5)
# Out:
#                                             html_url  \
# 0  https://github.com/kubernetes/kubernetes/pull/...
# 1  https://github.com/kubernetes/kubernetes/pull/...
# 2  https://github.com/kubernetes/kubernetes/pull/...
# 3  https://github.com/kubernetes/kubernetes/pull/...
# 4  https://github.com/kubernetes/kubernetes/pull/...
#
#                                               labels  number
# 0  [{'id': 105146071, 'node_id': 'MDU6TGFiZWwxMDU...   18072
# 1  [{'id': 105146071, 'node_id': 'MDU6TGFiZWwxMDU...   17654
# 2  [{'id': 105146071, 'node_id': 'MDU6TGFiZWwxMDU...   16992
# 3  [{'id': 105146071, 'node_id': 'MDU6TGFiZWwxMDU...   16223
# 4  [{'id': 105146071, 'node_id': 'MDU6TGFiZWwxMDU...   15772

# %%
# merge the prs and the data
data = data.merge(prs, left_on='pr_url', right_on='html_url', how='inner')

# remove html_url column
data.drop(columns=['html_url'], inplace=True)

print(f'new shape: {data.shape}')
# Out:
# new shape: (2274, 8)

# %%
data.head(5)
# Out:
#                                         comments_url          id  \
# 0  https://api.github.com/repos/kubernetes/kubern...  2639668210
# 1  https://api.github.com/repos/kubernetes/kubern...  2617512099
# 2  https://api.github.com/repos/kubernetes/kubern...  2604613192
# 3  https://api.github.com/repos/kubernetes/kubern...  2596132738
# 4  https://api.github.com/repos/kubernetes/kubern...  2595110543
#
#                                                title  \
# 0  kubelet crash: fatal error: concurrent map writes
# 1  [FG:InPlacePodVerticalScaling] failed to verif...
# 2          Restore build-tag flag for code-generator
# 3  [Failing Tests] ci-crio-cgroupv1-node-e2e-conf...
# 4  [Bug] Missing constraint and validation for la...
#
#                                                 body  \
# 0  ### What happened?\n\nWhile looking into three...
# 1  ### What happened?\n\nOne line bug description...
# 2  ### What happened?\n\nThe `build-tag` flag is ...
# ...

# %%
# extract the labels name only from labels column
data['labels'] = data['labels'].apply(lambda x: [label['name'] for label in x])

# filter the labels name to only have the area labels
data['labels'] = data['labels'].apply(lambda x: [label for label in x if label.startswith('area')])

# %%
print(f'before filter: {data.shape}')

# delete the row with no labels
data = data[data['labels'].apply(lambda x: len(x) > 0)]

print(f'after filter: {data.shape}')
# Out:
# before filter: (2274, 8)
# after filter: (1254, 8)

# %%
data.head(5)
# Out:
#                                         comments_url          id  \
# 0  https://api.github.com/repos/kubernetes/kubern...  2639668210
# 1  https://api.github.com/repos/kubernetes/kubern...  2617512099
# 2  https://api.github.com/repos/kubernetes/kubern...  2604613192
# 3  https://api.github.com/repos/kubernetes/kubern...  2596132738
# 5  https://api.github.com/repos/kubernetes/kubern...  2591358936
#
#                                                title  \
# 0  kubelet crash: fatal error: concurrent map writes
# 1  [FG:InPlacePodVerticalScaling] failed to verif...
# 2          Restore build-tag flag for code-generator
# 3  [Failing Tests] ci-crio-cgroupv1-node-e2e-conf...
# 5  Crash on kube manager's service-lb-controller ...
#
#                                                 body  \
# 0  ### What happened?\n\nWhile looking into three...
# 1  ### What happened?\n\nOne line bug description...
# 2  ### What happened?\n\nThe `build-tag` flag is ...
# ...

# %%
changed_files = pd.read_csv('../../Data/Data From API/Kind:Bug/pr_changed_files.csv')
changed_files.head(5)
# Out:
#    pr_number                                           filename  \
# 0      15772               ['test/e2e/scheduler_predicates.go']
# 1      17654             ['contrib/mesos/pkg/offers/offers.go']
# 2      16992  ['contrib/mesos/pkg/scheduler/podtask/port_map...
# 3      18072  ['contrib/mesos/pkg/executor/executor.go', 'co...
# 4      16223  ['pkg/kubelet/prober/worker_test.go', 'pkg/kub...
#
#                                  status      additions    deletions  \
# 0                          ['modified']            [7]          [1]
# 1                          ['modified']            [1]          [1]
# 2              ['modified', 'modified']        [4, 39]       [4, 0]
# 3  ['modified', 'modified', 'modified']      [1, 1, 3]    [1, 0, 1]
# 4  ['modified', 'modified', 'modified']  [3, 138, 121]  [1, 69, 13]
#
#          changes
# 0            [8]
# 1            [2]
# 2        [8, 39]
# 3      [2, 1, 4]
# 4  [4, 207, 134]

# %%
print(f'before merge: {data.shape}')

# merge the data with changed_files
data = data.merge(changed_files, left_on='number', right_on='pr_number', how='inner')

# remove pr_number column
data.drop(columns=['number'], inplace=True)

print(f'new shape: {data.shape}')
# Out:
# before merge: (1254, 8)
# new shape: (1258, 13)

# %%
data.head(5)
# Out:
#                                         comments_url          id  \
# 0  https://api.github.com/repos/kubernetes/kubern...  2639668210
# 1  https://api.github.com/repos/kubernetes/kubern...  2617512099
# 2  https://api.github.com/repos/kubernetes/kubern...  2604613192
# 3  https://api.github.com/repos/kubernetes/kubern...  2596132738
# 4  https://api.github.com/repos/kubernetes/kubern...  2591358936
#
#                                                title  \
# 0  kubelet crash: fatal error: concurrent map writes
# 1  [FG:InPlacePodVerticalScaling] failed to verif...
# 2          Restore build-tag flag for code-generator
# 3  [Failing Tests] ci-crio-cgroupv1-node-e2e-conf...
# 4  Crash on kube manager's service-lb-controller ...
#
#                                                 body  \
# 0  ### What happened?\n\nWhile looking into three...
# 1  ### What happened?\n\nOne line bug description...
# 2  ### What happened?\n\nThe `build-tag` flag is ...
# ...

# %%
# count the frequency of every label name
from collections import Counter

labels = Counter([label for labels in data['labels'] for label in labels])

for label, count in labels.most_common():
    print(f'{label}: {count}')
# Out:
# area/kubelet: 384
# area/test: 342
# area/apiserver: 244
# area/cloudprovider: 215
# area/kubectl: 164
# area/dependency: 94
# area/code-generation: 73
# area/provider/azure: 67
# area/ipvs: 52
# area/kubeadm: 51
# area/kube-proxy: 33
# area/provider/gcp: 33
# area/e2e-test-framework: 30
# area/release-eng: 23
# area/conformance: 17
# area/custom-resources: 17
# area/security: 11
# area/provider/vmware: 6
# area/etcd: 5
# area/provider/openstack: 5
# area/api: 4
# area/deflake: 3
# area/network-policy: 3
# area/code-organization: 3
# area/admission-control: 3
# area/ipv6: 3
# area/batch: 2
# area/provider/aws: 2
# area/logging: 1
# area/client-libraries: 1
# area/node-lifecycle: 1
# area/controller-manager: 1
# area/hw-accelerators: 1
# area/audit: 1
# area/stateful-apps: 1
# area/platform/gce: 1
# area/workload-api/daemonset: 1
# area/node-e2e: 1
# area/usability: 1

# %%
files = Counter([
    file.strip(" '")
    for fn in data['filename']
    for file in fn.strip("[]").split(',')
])

for file, count in files.most_common():
    print(f'{file}: {count}')
# Out:
# go.mod: 75
# go.sum: 73
# pkg/kubelet/kubelet.go: 58
# staging/src/k8s.io/apiextensions-apiserver/go.sum: 53
# staging/src/k8s.io/apiserver/go.sum: 51
# staging/src/k8s.io/apiserver/go.mod: 47
# staging/src/k8s.io/kube-aggregator/go.sum: 45
# staging/src/k8s.io/cloud-provider/go.sum: 42
# vendor/modules.txt: 40
# pkg/proxy/ipvs/proxier.go: 39
# staging/src/k8s.io/apiextensions-apiserver/go.mod: 38
# staging/src/k8s.io/component-base/go.sum: 35
# pkg/kubelet/kubelet_pods.go: 34
# staging/src/k8s.io/cli-runtime/go.sum: 33
# staging/src/k8s.io/controller-manager/go.sum: 32
# staging/src/k8s.io/client-go/go.sum: 31
# staging/src/k8s.io/legacy-cloud-providers/go.sum: 29
# staging/src/k8s.io/sample-apiserver/go.sum: 29
# staging/src/k8s.io/apimachinery/go.mod: 26
# staging/src/k8s.io/client-go/go.mod: 26
# staging/src/k8s.io/csi-translation-lib/go.sum: 26
# staging/src/k8s.io/kube-controller-manager/go.sum: 26
# staging/src/k8s.io/apimachinery/go.sum: 25
# ...

# %%
# export the data to json file
data.to_json('../../Data/Preprocessed Data/kind:bug/merged_data.json', orient='records')
