# %%
import pandas as pd
from spacy.cli import download
from sklearn.feature_extraction.text import CountVectorizer
from collections import Counter
import spacy

# %%
train_data = pd.read_csv('../../../Data/Preprocessed Data/kind:bug/Augmented Data/balanced/augmented data/augmented_data_with_gpt2_full.csv')
val_data = pd.read_csv('../../../Data/Preprocessed Data/kind:bug/Augmented Data/original data/preprocessed data/preprocessed_val_data.csv')

# %%
train_data.head()
# Out:
#                                         comments_url          id  \
# 0  https://api.github.com/repos/kubernetes/kubern...  2639668210
# 1  https://api.github.com/repos/kubernetes/kubern...  2617512099
# 2  https://api.github.com/repos/kubernetes/kubern...  2604613192
# 3  https://api.github.com/repos/kubernetes/kubern...  2596132738
# 4  https://api.github.com/repos/kubernetes/kubern...  2591358936
#
#                                                title  \
# 0  kubelet crash: fatal error: concurrent map writes
# 1  [FG:InPlacePodVerticalScaling] failed to verif...
# 2          Restore build-tag flag for code-generator
# 3  [Failing Tests] ci-crio-cgroupv1-node-e2e-conf...
# 4  Crash on kube manager's service-lb-controller ...
#
#                                                 body  \
# 0  ### What happened?\n\nWhile looking into three...
# 1  ### What happened?\n\nOne line bug description...
# 2  ### What happened?\n\nThe `build-tag` flag is ...
# 3  ### Which jobs are failing?\n* master-blocking...
# 4  ### What happened?\n\nIf kube manager is start...
#
#                                            issue_url  \
# 0  https://github.com/kubernetes/kubernetes/issue...
# 1  https://github.com/kubernetes/kubernetes/issue...
# 2  https://github.com/kubernetes/kubernetes/issue...
# 3  https://github.com/kubernetes/kubernetes/issue...
# 4  https://github.com/kubernetes/kubernetes/issue...
#
#                                               pr_url  \
# 0  https://github.com/kubernetes/kubernetes/pull/...
# 1  https://github.com/kubernetes/kubernetes/pull/...
# 2  https://github.com/kubernetes/kubernetes/pull/...
# 3  https://github.com/kubernetes/kubernetes/pull/...
# 4  https://github.com/kubernetes/kubernetes/pull/...
#
#                                 labels  pr_number  \
# 0                     ['area/kubelet']   128657.0
# 1                     ['area/kubelet']   126620.0
# 2             ['area/code-generation']   128259.0
# 3  ['area/kubeadm', 'area/dependency']   128175.0
# 4               ['area/cloudprovider']   128182.0
#
#                                             filename  \
# 0  ['pkg/kubelet/cm/container_manager_linux.go', ...
# 1  ['pkg/kubelet/status/state/checkpoint.go', 'pk...
# 2  ['staging/src/k8s.io/code-generator/cmd/conver...
# 3  ['go.mod', 'go.sum', 'hack/unwanted-dependenci...
# 4  ['cmd/kube-controller-manager/app/controllerma...
#
#                                               status  \
# 0   ['modified', 'modified', 'modified', 'modified']
# 1                  ['modified', 'modified', 'added']
# 2  ['modified', 'modified', 'modified', 'modified...
# 3  ['modified', 'modified', 'modified', 'modified...
# 4               ['modified', 'modified', 'modified']
#
#                                       additions  \
# 0                                [3, 4, 18, 75]
# 1                                 [42, 23, 166]
# 2                          [12, 1, 1, 12, 1, 1]
# 3  [1, 3, 1, 21, 9, 9, 4, 0, 10, 2, 2, 5, 8, 1]
# 4                                   [26, 12, 5]
#
#                                         deletions  \
# 0                                    [3, 3, 6, 0]
# 1                                     [26, 17, 0]
# 2                              [2, 1, 1, 1, 1, 1]
# 3  [1, 2, 0, 98, 8, 7, 6, 62, 11, 1, 4, 8, 11, 1]
# 4                                       [0, 1, 4]
#
#                                              changes  \
# 0                                     [6, 7, 24, 75]
# 1                                      [68, 40, 166]
# 2                               [14, 2, 2, 13, 2, 2]
# 3  [2, 5, 1, 119, 17, 16, 10, 62, 21, 3, 6, 13, 1...
# 4                                        [26, 13, 9]
#
#                                         all_comments  \
# 0  /sig node Thought to search for similar errors...
# 1  This issue is currently awaiting triage.\n\nIf...
# 2  @p0lyn0mial FYI /sig api-machinery /triage acc...
# 3  @drewhagen: The provided milestone is not vali...
# 4  This issue is currently awaiting triage.\n\nIf...
#
#                                             all_text  is_augmented
# 0  kubelet fatal concurrent map writes while look...         False
# 1  failed verify pod status checkpoint checksum b...         False
# 2  restore flag flag removed moved removed depend...         False
# 3  multiple which jobs are which tests are node c...         False
# 4  crash kube after kube manager started no looks...         False

# %%
# check for null values
train_data.isnull().sum()
# Out:
# comments_url    4382
# id                 0
# title              0
# body               0
# issue_url       4382
# pr_url          4382
# labels             0
# pr_number       4382
# filename        4382
# status          4382
# additions       4382
# deletions       4382
# changes         4382
# all_comments    4409
# all_text           0
# is_augmented       0
# dtype: int64

# %%
val_data.head()
# Out:
#                                         comments_url         id  \
# 0  https://api.github.com/repos/kubernetes/kubern...  452179309
# 1  https://api.github.com/repos/kubernetes/kubern...  452175013
# 2  https://api.github.com/repos/kubernetes/kubern...  451615547
# 3  https://api.github.com/repos/kubernetes/kubern...  451156427
# 4  https://api.github.com/repos/kubernetes/kubern...  451147670
#
#                                                title  \
# 0  Some CRDs that duplicate built-in group/versio...
# 1  Some CRDs that duplicate built-in group/versio...
# 2  Azure Disk detach backoff cancelled due to err...
# 3  "--kube-reserved-cgroup" kubelet option cannot...
# 4  Windows kubelet won't start "Failed to create ...
#
#                                                 body  \
# 0  **What happened**:\r\n\r\nCreated a CRD:\r\n``...
# 1  **What happened**:\r\nCreated a CRD with a gro...
# 2  **What happened**:\r\n\r\n#78298 made sure tha...
# 3  start kubelet with below config:\r\n```\r\n# r...
# 4  **What happened**:\r\n\r\nI replaced the kubel...
#
#                                            issue_url  \
# 0  https://github.com/kubernetes/kubernetes/issue...
# 1  https://github.com/kubernetes/kubernetes/issue...
# 2  https://github.com/kubernetes/kubernetes/issue...
# 3  https://github.com/kubernetes/kubernetes/issue...
# 4  https://github.com/kubernetes/kubernetes/issue...
#
#                                               pr_url  \
# 0  https://github.com/kubernetes/kubernetes/pull/...
# 1  https://github.com/kubernetes/kubernetes/pull/...
# 2  https://github.com/kubernetes/kubernetes/pull/...
# 3  https://github.com/kubernetes/kubernetes/pull/...
# 4  https://github.com/kubernetes/kubernetes/pull/...
#
#                                               labels  pr_number  \
# 0             ['area/test', 'area/custom-resources']      82035
# 1  ['area/test', 'area/custom-resources', 'area/d...      81436
# 2                             ['area/cloudprovider']      78700
# 3                                   ['area/kubelet']      78793
# 4                      ['area/test', 'area/kubelet']      78704
#
#                                             filename  \
# 0  ['staging/src/k8s.io/apiextensions-apiserver/p...
# 1  ['staging/src/k8s.io/apiextensions-apiserver/g...
# 2  ['staging/src/k8s.io/legacy-cloud-providers/az...
# 3  ['pkg/kubelet/cm/cgroup_manager_linux_test.go'...
# 4  ['pkg/kubelet/kubelet.go', 'pkg/kubelet/util/u...
#
#                                               status              additions  \
# 0      ['modified', 'modified', 'modified', 'added']        [1, 20, 9, 380]
# 1  ['modified', 'modified', 'modified', 'modified...  [1, 2, 1, 14, 5, 209]
# 2                           ['modified', 'modified']                 [2, 2]
# 3                           ['modified', 'modified']                [22, 2]
# 4  ['modified', 'modified', 'modified', 'modified...        [6, 2, 2, 3, 4]
#
#             deletions                changes  \
# 0        [0, 1, 0, 0]        [1, 21, 9, 380]
# 1  [0, 0, 0, 5, 1, 0]  [1, 2, 1, 19, 6, 209]
# 2              [2, 2]                 [4, 4]
# 3              [0, 2]                [22, 4]
# 4     [1, 2, 2, 7, 1]       [7, 4, 4, 10, 5]
#
#                                         all_comments  \
# 0  @connor1989 /sub Is anyone working on this? I'...
# 1  /cc @cheftako  haven't looked into the code ye...
# 2                                            /assign
# 3  /area kubelet\r\n/sig node\r\n @derekwaynecarr...
# 4  cc @adelina-t \r\n/priority critical-urgent /m...
#
#                                             all_text
# 0  crd duplicate reap etcd datum deletion create ...
# 1  crd duplicate openapi create crd define custom...
# 2  azure disk detach backoff cancel error azure d...
# 3  kubelet option find cgroup start kubelet kubel...
# 4  window kubelet start create listener podresour...

# %% [markdown]
# Check the label distribution

# %%
# Flatten the list of labels if it's a list of lists
flattened_labels = []
for label_list in train_data["labels"]:
    # Convert string representation of list to actual list
    if isinstance(label_list, str):
        # Remove brackets and split by comma
        clean_label_list = label_list.strip('[]').replace("'", "").split(', ')
    else:
        clean_label_list = label_list
    
    # Add each label to the flattened list
    flattened_labels.extend(clean_label_list)

# Print labels distribution count
label_counts = Counter(flattened_labels)
print("Label Distribution Count (Training Data):")

for i, (label, count) in enumerate(label_counts.most_common()):
    print(f"{i+1}. {label}: {count}")
# Out:
# Label Distribution Count (Training Data):
# 1. area/test: 309
# 2. area/kubelet: 304
# 3. area/code-generation: 231
# 4. area/kubeadm: 231
# 5. area/dependency: 231
# 6. area/cloudprovider: 231
# 7. area/apiserver: 231
# 8. area/api: 231
# 9. area/e2e-test-framework: 231
# 10. area/kubectl: 231
# 11. area/kube-proxy: 231
# 12. area/release-eng: 231
# 13. area/ipvs: 231
# 14. area/provider/gcp: 231
# 15. area/conformance: 231
# 16. area/batch: 231
# 17. area/deflake: 231
# 18. area/provider/azure: 231
# 19. area/network-policy: 231
# 20. area/client-libraries: 231
# 21. area/code-organization: 231
# 22. area/security: 231
# 23. area/etcd: 231
# 24. area/custom-resources: 231
# 25. area/provider/aws: 231

# %%
# Flatten the list of labels if it's a list of lists
flattened_labels = []
for label_list in val_data["labels"]:
    # Convert string representation of list to actual list
    if isinstance(label_list, str):
        # Remove brackets and split by comma
        clean_label_list = label_list.strip('[]').replace("'", "").split(', ')
    else:
        clean_label_list = label_list
    
    # Add each label to the flattened list
    flattened_labels.extend(clean_label_list)

# Print labels distribution count
label_counts = Counter(flattened_labels)
print("Label Distribution Count (Validation Data):")

for i, (label, count) in enumerate(label_counts.most_common()):
    print(f"{i+1}. {label}: {count}")
# Out:
# Label Distribution Count (Validation Data):
# 1. area/kubelet: 79
# 2. area/apiserver: 45
# 3. area/cloudprovider: 42
# 4. area/test: 32
# 5. area/kubectl: 29
# 6. area/kubeadm: 18
# 7. area/ipvs: 13
# 8. area/dependency: 12
# 9. area/custom-resources: 9
# 10. area/code-generation: 6
# 11. area/provider/vmware: 6
# 12. area/kube-proxy: 6
# 13. area/security: 6
# 14. area/provider/openstack: 5
# 15. area/conformance: 5
# 16. area/provider/azure: 3
# 17. area/e2e-test-framework: 2
# 18. area/provider/gcp: 1

# %% [markdown]
# Stopwords Removal

# %%
# remove stopwords using spaCy
try:
    nlp = spacy.load('en_core_web_sm')
except OSError:
    download('en_core_web_sm')
    nlp = spacy.load('en_core_web_sm')

train_data['all_text'] = train_data['all_text'].apply(lambda x: ' '.join([word.text for word in nlp(x) if not word.is_stop]))
val_data['all_text'] = val_data['all_text'].apply(lambda x: ' '.join([word.text for word in nlp(x) if not word.is_stop]))

# %%
# check null values in all_text column
# Display null values for all columns
print(f"Null all_text column : {train_data['all_text'].isnull().sum()}")
# Out:
# Null all_text column : 0

# %% [markdown]
# Data Lemmatization

# %%
# lematize the text using spaCy
train_data['all_text'] = train_data['all_text'].apply(lambda x: ' '.join([word.lemma_ for word in nlp(x)]))
val_data['all_text'] = val_data['all_text'].apply(lambda x: ' '.join([word.lemma_ for word in nlp(x)]))

# %%
# check all_text column for null values
print(f"Null all_text column : {train_data['all_text'].isnull().sum()}")
# Out:
# Null all_text column : 0

# %% [markdown]
# # Export the Data

# %%
train_data.head()
# Out:
#                                         comments_url          id  \
# 0  https://api.github.com/repos/kubernetes/kubern...  2639668210
# 1  https://api.github.com/repos/kubernetes/kubern...  2617512099
# 2  https://api.github.com/repos/kubernetes/kubern...  2604613192
# 3  https://api.github.com/repos/kubernetes/kubern...  2596132738
# 4  https://api.github.com/repos/kubernetes/kubern...  2591358936
#
#                                                title  \
# 0  kubelet crash: fatal error: concurrent map writes
# 1  [FG:InPlacePodVerticalScaling] failed to verif...
# 2          Restore build-tag flag for code-generator
# 3  [Failing Tests] ci-crio-cgroupv1-node-e2e-conf...
# 4  Crash on kube manager's service-lb-controller ...
#
#                                                 body  \
# 0  ### What happened?\n\nWhile looking into three...
# 1  ### What happened?\n\nOne line bug description...
# 2  ### What happened?\n\nThe `build-tag` flag is ...
# 3  ### Which jobs are failing?\n* master-blocking...
# 4  ### What happened?\n\nIf kube manager is start...
#
#                                            issue_url  \
# 0  https://github.com/kubernetes/kubernetes/issue...
# 1  https://github.com/kubernetes/kubernetes/issue...
# 2  https://github.com/kubernetes/kubernetes/issue...
# 3  https://github.com/kubernetes/kubernetes/issue...
# 4  https://github.com/kubernetes/kubernetes/issue...
#
#                                               pr_url  \
# 0  https://github.com/kubernetes/kubernetes/pull/...
# 1  https://github.com/kubernetes/kubernetes/pull/...
# 2  https://github.com/kubernetes/kubernetes/pull/...
# 3  https://github.com/kubernetes/kubernetes/pull/...
# 4  https://github.com/kubernetes/kubernetes/pull/...
#
#                                 labels  pr_number  \
# 0                     ['area/kubelet']   128657.0
# 1                     ['area/kubelet']   126620.0
# 2             ['area/code-generation']   128259.0
# 3  ['area/kubeadm', 'area/dependency']   128175.0
# 4               ['area/cloudprovider']   128182.0
#
#                                             filename  \
# 0  ['pkg/kubelet/cm/container_manager_linux.go', ...
# 1  ['pkg/kubelet/status/state/checkpoint.go', 'pk...
# 2  ['staging/src/k8s.io/code-generator/cmd/conver...
# 3  ['go.mod', 'go.sum', 'hack/unwanted-dependenci...
# 4  ['cmd/kube-controller-manager/app/controllerma...
#
#                                               status  \
# 0   ['modified', 'modified', 'modified', 'modified']
# 1                  ['modified', 'modified', 'added']
# 2  ['modified', 'modified', 'modified', 'modified...
# 3  ['modified', 'modified', 'modified', 'modified...
# 4               ['modified', 'modified', 'modified']
#
#                                       additions  \
# 0                                [3, 4, 18, 75]
# 1                                 [42, 23, 166]
# 2                          [12, 1, 1, 12, 1, 1]
# 3  [1, 3, 1, 21, 9, 9, 4, 0, 10, 2, 2, 5, 8, 1]
# 4                                   [26, 12, 5]
#
#                                         deletions  \
# 0                                    [3, 3, 6, 0]
# 1                                     [26, 17, 0]
# 2                              [2, 1, 1, 1, 1, 1]
# 3  [1, 2, 0, 98, 8, 7, 6, 62, 11, 1, 4, 8, 11, 1]
# 4                                       [0, 1, 4]
#
#                                              changes  \
# 0                                     [6, 7, 24, 75]
# 1                                      [68, 40, 166]
# 2                               [14, 2, 2, 13, 2, 2]
# 3  [2, 5, 1, 119, 17, 16, 10, 62, 21, 3, 6, 13, 1...
# 4                                        [26, 13, 9]
#
#                                         all_comments  \
# 0  /sig node Thought to search for similar errors...
# 1  This issue is currently awaiting triage.\n\nIf...
# 2  @p0lyn0mial FYI /sig api-machinery /triage acc...
# 3  @drewhagen: The provided milestone is not vali...
# 4  This issue is currently awaiting triage.\n\nIf...
#
#                                             all_text  is_augmented
# 0  kubelet fatal concurrent map write look fail e...         False
# 1  fail verify pod status checkpoint checksum dif...         False
# 2  restore flag flag remove move remove dependenc...         False
# 3  multiple job test node conformance test testgr...         False
# 4  crash kube kube manager start look like instan...         False

# %%
# count nan values in the train_data
train_data.isna().sum()
# Out:
# comments_url    4382
# id                 0
# title              0
# body               0
# issue_url       4382
# pr_url          4382
# labels             0
# pr_number       4382
# filename        4382
# status          4382
# additions       4382
# deletions       4382
# changes         4382
# all_comments    4409
# all_text           0
# is_augmented       0
# dtype: int64

# %%
print(train_data['all_text'][0])
print(val_data['all_text'][0])
# Out:
# kubelet fatal concurrent map write look fail e2e test allalpha find kubelet crash nov 07 fatal concurrent map write nov 07 goroutine 29497 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 nov 07 create goroutine 250 nov 07 expect log prow job encounter crash require particular alpha feature allalpha _ response _ gce paste output paste output wmic osarchitecture paste output container runtime plugin version
# crd duplicate reap etcd datum deletion create customresourcedefinition namespace foo foo foo foolist create crd define overlap type customresourcedefinition v1beta1 cluster customresourcedefinition customresourcedefinition customresourcedefinition customresourcedefinitionlist object boolean verify crd create delete overlap crd delete verify overlap crd crd create stuck crd yaml customresource deletion progress instancedeletioninprogress terminate creation deletion overlap type crd effect type store datum group prefix apiservice customresourcedefinition custom resource crd instance type define mean define delete customresourcedefinition define overlap apiservice customresourcedefinition type remove exist apiservice customresourcedefinition resource crd deletion robust solution crd [ ' staging / src / k8s.io / apiextension - apiserver / pkg / controller / finalizer / BUILD ' , ' staging / src / k8s.io / apiextension - apiserver / pkg / controller / finalizer / crd_finalizer.go ' , ' test / integration / etcd / BUILD ' , ' test / integration / etcd / crd_overlap_storage_test.go ' ]

# %%
# # export the train_data and val_data to csv
train_data.to_csv('preprocessed_train_data_no_filename.csv', index=False)
val_data.to_csv('preprocessed_val_data_no_filename.csv', index=False)
